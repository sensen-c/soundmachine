# %% [markdown]
# ### import pandas as pd
# import matplotlib.pyplot as plt
#
# x_train_text = pd.read_csv('../data/model_file/text_train_june.csv')
# x_test_text = pd.read_csv('../data/model_file/text_test_june.csv')
#
# y_train_text = x_train_text['label']
# y_test_text = x_test_text['label']
#
# x_train_audio = pd.read_csv('../data/model_file/audio_train_june.csv')
# x_test_audio = pd.read_csv('../data/model_file/audio_test_june.csv')
#
# y_train_audio = x_train_audio['label']
# y_test_audio = x_test_audio['label']
#
# y_train = y_train_audio # since y_train_audio == y_train_text
# y_test = y_test_audio # since y_train_audio == y_train_text
#
# print(x_train_text.shape, y_train_text.shape, x_train_audio.shape, y_train_audio.shape)
# print(x_test_text.shape, y_test_text.shape, x_test_audio.shape, y_test_audio.shape)# combine the features upon on wav file name then spli to trainand text

# %%
import numpy as np
import itertools
from sklearn.metrics import f1_score, recall_score, precision_score,accuracy_score,confusion_matrix

# %%
# emotion_dict = {'ang': 0,
#                 'hap': 1,
#                 'sad': 2,
#                 'fea': 3,
#                 'sur': 4,
#                 'neu': 5}
emotion_dict = {'ang': 0, 
                'hap': 1, 
                'exc': 2,
                'sad': 3,
                'fru': 4,
                'fea': 5,
                'sur': 6,
                'neu': 7,
                'oth': 8}

emo_keys = list(emotion_dict.keys())

id_to_emotion = {emotion_dict[key]: key for key in emo_keys}

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    # plt.figure(figsize=(8,8))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
def one_hot_encoder(true_labels, num_records, num_classes):
    temp = np.array(true_labels[:num_records])
    true_labels = np.zeros((num_records, num_classes))
    true_labels[np.arange(num_records), temp] = 1
    return true_labels

def display_results(y_test, pred_probs, cm=True):
    pred = np.argmax(pred_probs, axis=-1)
    one_hot_true = one_hot_encoder(y_test, len(pred), len(emotion_dict))
    print('Test Set Accuracy =  {0:.3f}'.format(accuracy_score(y_test, pred)))
    print('Test Set F-score =  {0:.3f}'.format(f1_score(y_test, pred, average='macro')))
    print('Test Set Precision =  {0:.3f}'.format(precision_score(y_test, pred, average='macro')))
    print('Test Set Recall =  {0:.3f}'.format(recall_score(y_test, pred, average='macro')))
    if cm:
        plot_confusion_matrix(confusion_matrix(y_test, pred), classes=emo_keys)

# %%
cl_weight = dict(pd.Series(x_train_text['label']).value_counts(normalize=True))
cl_weight
# Out:
# {0: 0.141875,
#  3: 0.139375,
#  2: 0.138125,
#  7: 0.13765625,
#  8: 0.13640625,
#  4: 0.13484375,
#  1: 0.134375,
#  6: 0.026875,
#  5: 0.01046875}

# %%
cl_weight = dict(pd.Series(x_train_text['label']).value_counts(normalize=True))
sample_weights = pd.Series(x_train_text['label']).map(cl_weight)

# %% [markdown]
# ## Get Text Features

# %%
# tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 2), stop_words='english',max_features=100)
# 
# _ = pd.concat([x_train_text,x_test_text])
# 
# features_text = tfidf.fit_transform(_.transcription).toarray()
# 
# x_train_text = features_text[:x_train_text.shape[0]]
# x_test_text = features_text[-x_test_text.shape[0]:]
# 
# print(features_text.shape, x_train_text.shape, x_test_text.shape)

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import pickle

# Assuming x_train_text and x_test_text are your input data.
tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 2), stop_words='english', max_features=100)
all_text = pd.concat([x_train_text, x_test_text])  # Concatenate training and testing text data


# Save the fitted TfidfVectorizer
tfidf_vectorizer_filename = 'tfidf_vectorizer.pkl'
with open(tfidf_vectorizer_filename, 'wb') as file:
    pickle.dump(tfidf, file)
print(f"TfidfVectorizer saved to {tfidf_vectorizer_filename}")

# Fit the vectorizer and transform the text data to TF-IDF features
features_text = tfidf.fit_transform(all_text.transcription).toarray()

# Get feature names (column names) from the vectorizer
feature_names = tfidf.get_feature_names_out()

# Split the features back into training and testing sets and convert them to DataFrames with feature names
x_train_text = pd.DataFrame(features_text[:x_train_text.shape[0]], columns=feature_names)
x_test_text = pd.DataFrame(features_text[-x_test_text.shape[0]:], columns=feature_names)

print("Features matrix:", features_text.shape)
print("Train features DataFrame:", x_train_text.shape)
print("Test features DataFrame:", x_test_text.shape)
# Out:
# Features matrix: (8001, 100)
# Train features DataFrame: (6400, 100)
# Test features DataFrame: (1601, 100)

# %%
#examples
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import pickle

# Assuming x_train_text and x_test_text are your input data.
tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 2), stop_words='english', max_features=100)
all_text = pd.concat([x_train_text, x_test_text])  # Concatenate training and testing text data

# Fit the vectorizer and transform the text data to TF-IDF features
features_text = tfidf.fit_transform(all_text.transcription).toarray()

# Get feature names (column names) from the vectorizer
feature_names = tfidf.get_feature_names_out()

# Split the features back into training and testing sets and convert them to DataFrames with feature names
x_train_text_df = pd.DataFrame(features_text[:x_train_text.shape[0]], columns=feature_names)
x_test_text_df = pd.DataFrame(features_text[-x_test_text.shape[0]:], columns=feature_names)

# Save the fitted TfidfVectorizer
tfidf_vectorizer_filename = 'tfidf_vectorizer.pkl'
with open(tfidf_vectorizer_filename, 'wb') as file:
    pickle.dump(tfidf, file)
print(f"TfidfVectorizer saved to {tfidf_vectorizer_filename}")

# Save the transformed training features to a CSV file
x_train_text_filename = 'x_train_text_tfidf.csv'
x_train_text_df.to_csv(x_train_text_filename, index=False)
print(f"Transformed training features saved to {x_train_text_filename}")

# Save the transformed testing features to a CSV file
x_test_text_filename = 'x_test_text_tfidf.csv'
x_test_text_df.to_csv(x_test_text_filename, index=False)
print(f"Transformed testing features saved to {x_test_text_filename}")

# Save the labels if needed
y_train_filename = 'y_train.csv'
y_train.to_csv(y_train_filename, index=False)
print(f"Training labels saved to {y_train_filename}")

y_test_filename = 'y_test.csv'
y_test.to_csv(y_test_filename, index=False)
print(f"Testing labels saved to {y_test_filename}")

print("Features matrix:", features_text.shape)
print("Train features DataFrame:", x_train_text_df.shape)
print("Test features DataFrame:", x_test_text_df.shape)

import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import pickle

# Assuming x_train_text and x_test_text are your input data.
tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 2), stop_words='english', max_features=100)
all_text = pd.concat([x_train_text, x_test_text])  # Concatenate training and testing text data

# Fit the vectorizer and transform the text data to TF-IDF features
features_text = tfidf.fit_transform(all_text.transcription).toarray()

# Get feature names (column names) from the vectorizer
feature_names = tfidf.get_feature_names_out()

# Split the features back into training and testing sets and convert them to DataFrames with feature names
x_train_text_df = pd.DataFrame(features_text[:x_train_text.shape[0]], columns=feature_names)
x_test_text_df = pd.DataFrame(features_text[-x_test_text.shape[0]:], columns=feature_names)

# Save the fitted TfidfVectorizer
tfidf_vectorizer_filename = 'tfidf_vectorizer.pkl'
with open(tfidf_vectorizer_filename, 'wb') as file:
    pickle.dump(tfidf, file)
print(f"TfidfVectorizer saved to {tfidf_vectorizer_filename}")

# Save the transformed training features to a CSV file
x_train_text_filename = 'x_train_text_tfidf.csv'
x_train_text_df.to_csv(x_train_text_filename, index=False)
print(f"Transformed training features saved to {x_train_text_filename}")

# Save the transformed testing features to a CSV file
x_test_text_filename = 'x_test_text_tfidf.csv'
x_test_text_df.to_csv(x_test_text_filename, index=False)
print(f"Transformed testing features saved to {x_test_text_filename}")

# Save the labels if needed
y_train_filename = 'y_train.csv'
y_train.to_csv(y_train_filename, index=False)
print(f"Training labels saved to {y_train_filename}")

y_test_filename = 'y_test.csv'
y_test.to_csv(y_test_filename, index=False)
print(f"Testing labels saved to {y_test_filename}")

print("Features matrix:", features_text.shape)
print("Train features DataFrame:", x_train_text_df.shape)
print("Test features DataFrame:", x_test_text_df.shape)

# %% [markdown]
# ## Combine Text + Audio Features

# %%
x_train_audio.count()
# Out:
# wav_file         6400
# label            6400
# sig_mean         6400
# sig_std          6400
# rmse_mean        6400
# rmse_std         6400
# silence          6400
# harmonic         6400
# auto_corr_max    6400
# auto_corr_std    6400
# mfcc_1_mean      6400
# mfcc_2_mean      6400
# mfcc_3_mean      6400
# mfcc_4_mean      6400
# mfcc_5_mean      6400
# mfcc_6_mean      6400
# mfcc_7_mean      6400
# mfcc_8_mean      6400
# mfcc_9_mean      6400
# mfcc_10_mean     6400
# mfcc_11_mean     6400
# mfcc_12_mean     6400
# mfcc_13_mean     6400
# mfcc_1_std       6400
# mfcc_2_std       6400
# mfcc_3_std       6400
# mfcc_4_std       6400
# mfcc_5_std       6400
# mfcc_6_std       6400
# mfcc_7_std       6400
# mfcc_8_std       6400
# mfcc_9_std       6400
# mfcc_10_std      6400
# mfcc_11_std      6400
# mfcc_12_std      6400
# mfcc_13_std      6400
# mel_mean         6400
# mel_std          6400
# dtype: int64

# %%
x_train_text.count()
# Out:
# annie       6400
# ask         6400
# away        6400
# believe     6400
# business    6400
#             ...
# wrong       6400
# yeah        6400
# year        6400
# years       6400
# yes         6400
# Length: 100, dtype: int64

# %%
# x_train_audio_selected.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 x_train_audio_selected.columns
#
# NameError: name 'x_train_audio_selected' is not defined

# %%
x_train_audio_selected = x_train_audio[x_train_audio.columns.difference(['wav_file', 'label'])]
x_train_audio_array = np.array(x_train_audio_selected)
x_test_audio_selected = x_test_audio[x_test_audio.columns.difference(['wav_file', 'label'])]
x_test_audio_array = np.array(x_test_audio_selected)

combined_x_train = np.concatenate((x_train_audio_array, x_train_text), axis=1)
# combined_x_train = x_train_audio_array

combined_x_test = np.concatenate((x_test_audio_array, x_test_text), axis=1)
# combined_x_test = x_test_audio_array

print(combined_x_train.shape, combined_x_test.shape)

combined_features_dict = {}

combined_features_dict['x_train'] = combined_x_train
combined_features_dict['x_test'] = combined_x_test
combined_features_dict['y_train'] = np.array(y_train)
combined_features_dict['y_test'] = np.array(y_test)

# with open('../data/model_file/combined_features.pkl', 'wb') as f:
#     pickle.dump(combined_features_dict, f)
# Out:
# (6400, 136) (1601, 136)

# %%
combined_x_train
# Out:
# array([[ 1.44921596e-02,  3.90679849e-01, -6.07776974e-03, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 1.20193576e-03,  2.03072191e-02, -8.96750862e-03, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 4.14353626e-03,  4.83182747e-02, -5.78340359e-03, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        ...,
#        [ 6.73682818e-04,  5.55917132e-03, -1.03971406e-02, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 1.05190534e-03,  1.22244869e-02, -8.00284761e-03, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 1.70810116e-01,  2.31700952e+00, -5.45614375e-03, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00]])

# %%
# rf_classifier = RandomForestClassifier(n_estimators=600, min_samples_split=25)
# rf_classifier.fit(combined_x_train, y_train)
# 
# # Predict
# pred_probs = rf_classifier.predict_proba(combined_x_test)
# 
# # Results
# display_results(y_test, pred_probs)
# 
# with open('../data/model/pred_probas/combined_rf_classifier.pkl', 'wb') as f:
#     pickle.dump(pred_probs, f)
# 
# with open('../data/model/combined_RF.pkl', 'wb') as f:
#     pickle.dump(rf_classifier, f)

# %%
import xgboost as xgb
import pickle

xgb_classifier = xgb.XGBClassifier(booster= 'gbtree', colsample_bytree= 0.3, learning_rate= 0.05, max_depth= 7, n_estimators= 300, subsample=0.8, n_jobs=4,cl_weight=cl_weight,random_stat=42)
xgb_classifier.fit(combined_x_train, y_train)
#Best parameters found:  {'booster': 'gbtree', 'colsample_bytree': 0.3, 'learning_rate': 0.05, 'max_depth': 7, 'n_estimators': 300, 'subsample': 0.8}


# Predict
pred_probs = xgb_classifier.predict_proba(combined_x_test)

# Results
display_results(y_test, pred_probs)

# with open('../data/model/pred_probas/combined_xgb_classifier_previous.pkl', 'wb') as f:
#     pickle.dump(pred_probs, f)
# 
# with open('../data/model/combined_XGB_previous.pkl', 'wb') as f:
#     pickle.dump(xgb_classifier, f)
# Out:
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [23:43:00] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "cl_weight", "random_stat" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Test Set Accuracy =  0.631
# Test Set F-score =  0.685
# Test Set Precision =  0.690
# Test Set Recall =  0.689
# Confusion matrix, without normalization
# [[135   3   4   1  28   0   0   9  13]
#  [  5 175  22  18   6   0   0  11   4]
#  [ 14  16 150   3   7   0   0  14  13]
#  [  1   3   2 182   7   1   0  10   3]
#  [ 28   5  15  14 133   0   0  25  18]
#  [  0   0   0   0   0  13   0   0   0]
#  [  0   2   0   0   2   0  34   0   4]
#  [  7   6  13  21  25   0   0 121  27]
#  [ 13  22  39  30  29   0   0  27  68]]

# %%
# Save the best model using pickle
model_filename = 'best_xgboost_model.pkl'
with open(model_filename, 'wb') as file:
    pickle.dump(best_model, file)
print(f"Model saved to {model_filename}")
# Out:
# Fitting 3 folds for each of 216 candidates, totalling 648 fits
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 2182, in precision_score
#     p, _, _, _ = precision_recall_fscore_support(
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1767, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1556, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 2182, in precision_score
#     p, _, _, _ = precision_recall_fscore_support(
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1767, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1556, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 2182, in precision_score
#     p, _, _, _ = precision_recall_fscore_support(
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1767, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1556, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 2182, in precision_score
#     p, _, _, _ = precision_recall_fscore_support(
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1767, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1556, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 2182, in precision_score
#     p, _, _, _ = precision_recall_fscore_support(
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1767, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1556, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 2182, in precision_score
#     p, _, _, _ = precision_recall_fscore_support(
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1767, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1556, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 2182, in precision_score
#     p, _, _, _ = precision_recall_fscore_support(
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1767, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1556, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 2182, in precision_score
#     p, _, _, _ = precision_recall_fscore_support(
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1767, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1556, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 2182, in precision_score
#     p, _, _, _ = precision_recall_fscore_support(
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1767, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1556, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 2182, in precision_score
#     p, _, _, _ = precision_recall_fscore_support(
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1767, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1556, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 2182, in precision_score
#     p, _, _, _ = precision_recall_fscore_support(
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1767, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1556, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 2182, in precision_score
#     p, _, _, _ = precision_recall_fscore_support(
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1767, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1556, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 2182, in precision_score
#     p, _, _, _ = precision_recall_fscore_support(
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1767, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1556, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 2182, in precision_score
#     p, _, _, _ = precision_recall_fscore_support(
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1767, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1556, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 2182, in precision_score
#     p, _, _, _ = precision_recall_fscore_support(
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1767, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1556, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 2182, in precision_score
#     p, _, _, _ = precision_recall_fscore_support(
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1767, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1556, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 2182, in precision_score
#     p, _, _, _ = precision_recall_fscore_support(
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1767, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1556, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 2182, in precision_score
#     p, _, _, _ = precision_recall_fscore_support(
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1767, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1556, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 2182, in precision_score
#     p, _, _, _ = precision_recall_fscore_support(
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1767, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1556, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 2182, in precision_score
#     p, _, _, _ = precision_recall_fscore_support(
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1767, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1556, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 2182, in precision_score
#     p, _, _, _ = precision_recall_fscore_support(
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1767, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1556, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 2182, in precision_score
#     p, _, _, _ = precision_recall_fscore_support(
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1767, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1556, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 2182, in precision_score
#     p, _, _, _ = precision_recall_fscore_support(
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
# ...
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 2182, in precision_score
#     p, _, _, _ = precision_recall_fscore_support(
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1767, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1556, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 2182, in precision_score
#     p, _, _, _ = precision_recall_fscore_support(
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1767, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1556, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 2182, in precision_score
#     p, _, _, _ = precision_recall_fscore_support(
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1767, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1556, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 2182, in precision_score
#     p, _, _, _ = precision_recall_fscore_support(
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1767, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1556, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[85], line 32
#      23 # Initialize GridSearchCV
#      24 grid_search = GridSearchCV(
#      25     estimator=xgb_classifier,
#      26     param_grid=param_grid,
#    (...)
#      29     verbose=1
#      30 )
# ---> 32 grid_search.fit(combined_x_train, y_train, sample_weight=sample_weights)
#      34 best_params = grid_search.best_params_
#      35 print("Best parameters found: ", best_params)
#
# File ~/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_search.py:970, in BaseSearchCV.fit(self, X, y, **params)
#     964     results = self._format_results(
#     965         all_candidate_params, n_splits, all_out, all_more_results
#     966     )
#     968     return results
# --> 970 self._run_search(evaluate_candidates)
#     972 # multimetric is determined here because in the case of a callable
#     973 # self.scoring the return type is only known after calling
#     974 first_test_score = all_out[0]["test_scores"]
#
# File ~/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_search.py:1527, in GridSearchCV._run_search(self, evaluate_candidates)
#    1525 def _run_search(self, evaluate_candidates):
#    1526     """Search all candidates in param_grid"""
# -> 1527     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_search.py:916, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     908 if self.verbose > 0:
#     909     print(
#     910         "Fitting {0} folds for each of {1} candidates,"
#     911         " totalling {2} fits".format(
#     912             n_splits, n_candidates, n_candidates * n_splits
#     913         )
#     914     )
# --> 916 out = parallel(
#     917     delayed(_fit_and_score)(
#     918         clone(base_estimator),
#     919         X,
#     920         y,
#     921         train=train,
#     922         test=test,
#     923         parameters=parameters,
#     924         split_progress=(split_idx, n_splits),
#     925         candidate_progress=(cand_idx, n_candidates),
#     926         **fit_and_score_kwargs,
#     927     )
#     928     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     929         enumerate(candidate_params),
#     930         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     931     )
#     932 )
#     934 if len(out) < 1:
#     935     raise ValueError(
#     936         "No fits were performed. "
#     937         "Was the CV iterator empty? "
#     938         "Were there no candidates?"
#     939     )
#
# File ~/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/parallel.py:67, in Parallel.__call__(self, iterable)
#      62 config = get_config()
#      63 iterable_with_config = (
#      64     (_with_config(delayed_func, config), args, kwargs)
#      65     for delayed_func, args, kwargs in iterable
#      66 )
# ---> 67 return super().__call__(iterable_with_config)
#
# File ~/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/joblib/parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File ~/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/joblib/parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File ~/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/utils/parallel.py:129, in _FuncWrapper.__call__(self, *args, **kwargs)
#     127     config = {}
#     128 with config_context(**config):
# --> 129     return self.function(*args, **kwargs)
#
# File ~/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:895, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     893         estimator.fit(X_train, **fit_params)
#     894     else:
# --> 895         estimator.fit(X_train, y_train, **fit_params)
#     897 except Exception:
#     898     # Note fit time as time until error
#     899     fit_time = time.time() - start_time
#
# File ~/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:730, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     728 for k, arg in zip(sig.parameters, args):
#     729     kwargs[k] = arg
# --> 730 return func(**kwargs)
#
# File ~/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/sklearn.py:1519, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1491 (
#    1492     model,
#    1493     metric,
#    (...)
#    1498     xgb_model, eval_metric, params, early_stopping_rounds, callbacks
#    1499 )
#    1500 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1501     missing=self.missing,
#    1502     X=X,
#    (...)
#    1516     feature_types=self.feature_types,
#    1517 )
# -> 1519 self._Booster = train(
#    1520     params,
#    1521     train_dmatrix,
#    1522     self.get_num_boosting_rounds(),
#    1523     evals=evals,
#    1524     early_stopping_rounds=early_stopping_rounds,
#    1525     evals_result=evals_result,
#    1526     obj=obj,
#    1527     custom_metric=metric,
#    1528     verbose_eval=verbose,
#    1529     xgb_model=model,
#    1530     callbacks=callbacks,
#    1531 )
#    1533 if not callable(self.objective):
#    1534     self.objective = params["objective"]
#
# File ~/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:730, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     728 for k, arg in zip(sig.parameters, args):
#     729     kwargs[k] = arg
# --> 730 return func(**kwargs)
#
# File ~/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, i, obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File ~/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:2051, in Booster.update(self, dtrain, iteration, fobj)
#    2047 self._assign_dmatrix_features(dtrain)
#    2049 if fobj is None:
#    2050     _check_call(
# -> 2051         _LIB.XGBoosterUpdateOneIter(
#    2052             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2053         )
#    2054     )
#    2055 else:
#    2056     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
import xgboost as xgb
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.metrics import make_scorer, precision_score

# Define a custom scorer for precision with 'macro' averaging
precision_macro = make_scorer(precision_score, average='macro')
import pandas as pd

# Define the parameter grid
param_grid = {
    'max_depth': [7,10],
    'learning_rate': [0.05],
    'n_estimators': [200,300],
    'booster': ['gbtree'],
    'colsample_bytree': [0.7],
    'subsample': [0.5, 0.8],
    'reg_alpha': [0, 0.01, 0.1],
    'reg_lambda': [1, 1.5, 2],
    'min_child_weight': [1, 5, 10]
}

# Initialize the XGBClassifier
xgb_classifier = xgb.XGBClassifier(
    objective='multi:softprob', 
    num_class=len(cl_weight), 
    n_jobs=10, 
    random_state=42
)

# Define the stratified k-fold cross-validator
skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

# Initialize GridSearchCV
grid_search = GridSearchCV(
    estimator=xgb_classifier, 
    param_grid=param_grid, 
    cv=skf, 
    scoring=precision_macro, 
    verbose=1
)

# Fit the grid search
grid_search.fit(combined_x_train, y_train, sample_weight=sample_weights)

# Best parameters
best_params = grid_search.best_params_
print("Best parameters found: ", best_params)

# Best model
best_model = grid_search.best_estimator_

# Early stopping with a validation set
eval_set = [(combined_x_train, y_train), (combined_x_test, y_test)]
best_model.fit(
    combined_x_train, y_train,
    eval_metric="mlogloss",
    eval_set=eval_set,
    # early_stopping_rounds=10,
    sample_weight=sample_weights
)

# Evaluate on the training set
train_predictions = best_model.predict(combined_x_train)
train_accuracy = accuracy_score(y_train, train_predictions)
train_classification_report = classification_report(y_train, train_predictions)
train_confusion_matrix = confusion_matrix(y_train, train_predictions)

print("Training set performance:")
print("Accuracy: ", train_accuracy)
print("Classification Report:\n", train_classification_report)
print("Confusion Matrix:\n", train_confusion_matrix)

# Evaluate on the test set
test_predictions = best_model.predict(combined_x_test)
test_accuracy = accuracy_score(y_test, test_predictions)
test_classification_report = classification_report(y_test, test_predictions)
test_confusion_matrix = confusion_matrix(y_test, test_predictions)

print("Test set performance:")
print("Accuracy: ", test_accuracy)
print("Classification Report:\n", test_classification_report)
print("Confusion Matrix:\n", test_confusion_matrix)


# Save the best model using pickle
model_filename = '../data/model/best_xgboost_model_without_early_stop.pkl'
with open(model_filename, 'wb') as file:
    pickle.dump(best_model, file)
print(f"Model saved to {model_filename}")
# Out:
# Fitting 3 folds for each of 216 candidates, totalling 648 fits
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...
# [127]	validation_0-mlogloss:0.85385	validation_1-mlogloss:1.42451
# [128]	validation_0-mlogloss:0.85085	validation_1-mlogloss:1.42328
# [129]	validation_0-mlogloss:0.84718	validation_1-mlogloss:1.42190
# [130]	validation_0-mlogloss:0.84331	validation_1-mlogloss:1.42052
# [131]	validation_0-mlogloss:0.84008	validation_1-mlogloss:1.41934
# [132]	validation_0-mlogloss:0.83718	validation_1-mlogloss:1.41804
# [133]	validation_0-mlogloss:0.83401	validation_1-mlogloss:1.41666
# [134]	validation_0-mlogloss:0.83098	validation_1-mlogloss:1.41579
# [135]	validation_0-mlogloss:0.82835	validation_1-mlogloss:1.41497
# [136]	validation_0-mlogloss:0.82521	validation_1-mlogloss:1.41326
# [137]	validation_0-mlogloss:0.82185	validation_1-mlogloss:1.41167
# [138]	validation_0-mlogloss:0.81958	validation_1-mlogloss:1.41095
# [139]	validation_0-mlogloss:0.81668	validation_1-mlogloss:1.40977
# [140]	validation_0-mlogloss:0.81368	validation_1-mlogloss:1.40856
# [141]	validation_0-mlogloss:0.81039	validation_1-mlogloss:1.40712
# [142]	validation_0-mlogloss:0.80730	validation_1-mlogloss:1.40592
# [143]	validation_0-mlogloss:0.80463	validation_1-mlogloss:1.40488
# [144]	validation_0-mlogloss:0.80185	validation_1-mlogloss:1.40363
# [145]	validation_0-mlogloss:0.79884	validation_1-mlogloss:1.40217
# [146]	validation_0-mlogloss:0.79593	validation_1-mlogloss:1.40124
# [147]	validation_0-mlogloss:0.79314	validation_1-mlogloss:1.40040
# [148]	validation_0-mlogloss:0.79016	validation_1-mlogloss:1.39972
# [149]	validation_0-mlogloss:0.78706	validation_1-mlogloss:1.39870
# [150]	validation_0-mlogloss:0.78457	validation_1-mlogloss:1.39760
# [151]	validation_0-mlogloss:0.78197	validation_1-mlogloss:1.39680
# [152]	validation_0-mlogloss:0.77865	validation_1-mlogloss:1.39584
# [153]	validation_0-mlogloss:0.77664	validation_1-mlogloss:1.39497
# [154]	validation_0-mlogloss:0.77421	validation_1-mlogloss:1.39404
# [155]	validation_0-mlogloss:0.77135	validation_1-mlogloss:1.39315
# [156]	validation_0-mlogloss:0.76872	validation_1-mlogloss:1.39217
# [157]	validation_0-mlogloss:0.76601	validation_1-mlogloss:1.39135
# [158]	validation_0-mlogloss:0.76317	validation_1-mlogloss:1.39021
# [159]	validation_0-mlogloss:0.76053	validation_1-mlogloss:1.38929
# [160]	validation_0-mlogloss:0.75804	validation_1-mlogloss:1.38840
# [161]	validation_0-mlogloss:0.75564	validation_1-mlogloss:1.38760
# [162]	validation_0-mlogloss:0.75293	validation_1-mlogloss:1.38645
# [163]	validation_0-mlogloss:0.75088	validation_1-mlogloss:1.38548
# [164]	validation_0-mlogloss:0.74862	validation_1-mlogloss:1.38469
# [165]	validation_0-mlogloss:0.74608	validation_1-mlogloss:1.38377
# [166]	validation_0-mlogloss:0.74346	validation_1-mlogloss:1.38301
# [167]	validation_0-mlogloss:0.74077	validation_1-mlogloss:1.38221
# [168]	validation_0-mlogloss:0.73807	validation_1-mlogloss:1.38104
# [169]	validation_0-mlogloss:0.73521	validation_1-mlogloss:1.38013
# [170]	validation_0-mlogloss:0.73270	validation_1-mlogloss:1.37901
# [171]	validation_0-mlogloss:0.73062	validation_1-mlogloss:1.37832
# [172]	validation_0-mlogloss:0.72744	validation_1-mlogloss:1.37741
# [173]	validation_0-mlogloss:0.72431	validation_1-mlogloss:1.37609
# [174]	validation_0-mlogloss:0.72114	validation_1-mlogloss:1.37480
# [175]	validation_0-mlogloss:0.71839	validation_1-mlogloss:1.37377
# [176]	validation_0-mlogloss:0.71586	validation_1-mlogloss:1.37297
# [177]	validation_0-mlogloss:0.71330	validation_1-mlogloss:1.37210
# [178]	validation_0-mlogloss:0.71086	validation_1-mlogloss:1.37139
# [179]	validation_0-mlogloss:0.70779	validation_1-mlogloss:1.37008
# [180]	validation_0-mlogloss:0.70539	validation_1-mlogloss:1.36930
# [181]	validation_0-mlogloss:0.70315	validation_1-mlogloss:1.36821
# [182]	validation_0-mlogloss:0.70150	validation_1-mlogloss:1.36759
# [183]	validation_0-mlogloss:0.69919	validation_1-mlogloss:1.36663
# [184]	validation_0-mlogloss:0.69698	validation_1-mlogloss:1.36566
# [185]	validation_0-mlogloss:0.69452	validation_1-mlogloss:1.36475
# [186]	validation_0-mlogloss:0.69175	validation_1-mlogloss:1.36375
# [187]	validation_0-mlogloss:0.68916	validation_1-mlogloss:1.36277
# [188]	validation_0-mlogloss:0.68654	validation_1-mlogloss:1.36179
# [189]	validation_0-mlogloss:0.68425	validation_1-mlogloss:1.36091
# [190]	validation_0-mlogloss:0.68169	validation_1-mlogloss:1.35984
# [191]	validation_0-mlogloss:0.67962	validation_1-mlogloss:1.35882
# [192]	validation_0-mlogloss:0.67699	validation_1-mlogloss:1.35758
# [193]	validation_0-mlogloss:0.67442	validation_1-mlogloss:1.35672
# [194]	validation_0-mlogloss:0.67167	validation_1-mlogloss:1.35542
# [195]	validation_0-mlogloss:0.66971	validation_1-mlogloss:1.35459
# [196]	validation_0-mlogloss:0.66739	validation_1-mlogloss:1.35368
# [197]	validation_0-mlogloss:0.66517	validation_1-mlogloss:1.35260
# [198]	validation_0-mlogloss:0.66293	validation_1-mlogloss:1.35186
# [199]	validation_0-mlogloss:0.66084	validation_1-mlogloss:1.35102
# [200]	validation_0-mlogloss:0.65892	validation_1-mlogloss:1.35009
# [201]	validation_0-mlogloss:0.65682	validation_1-mlogloss:1.34953
# [202]	validation_0-mlogloss:0.65429	validation_1-mlogloss:1.34896
# [203]	validation_0-mlogloss:0.65181	validation_1-mlogloss:1.34782
# [204]	validation_0-mlogloss:0.64972	validation_1-mlogloss:1.34707
# [205]	validation_0-mlogloss:0.64725	validation_1-mlogloss:1.34585
# [206]	validation_0-mlogloss:0.64531	validation_1-mlogloss:1.34492
# [207]	validation_0-mlogloss:0.64283	validation_1-mlogloss:1.34432
# [208]	validation_0-mlogloss:0.64090	validation_1-mlogloss:1.34356
# [209]	validation_0-mlogloss:0.63897	validation_1-mlogloss:1.34297
# [210]	validation_0-mlogloss:0.63704	validation_1-mlogloss:1.34216
# [211]	validation_0-mlogloss:0.63488	validation_1-mlogloss:1.34145
# [212]	validation_0-mlogloss:0.63284	validation_1-mlogloss:1.34084
# [213]	validation_0-mlogloss:0.63037	validation_1-mlogloss:1.34006
# [214]	validation_0-mlogloss:0.62837	validation_1-mlogloss:1.33910
# [215]	validation_0-mlogloss:0.62644	validation_1-mlogloss:1.33849
# [216]	validation_0-mlogloss:0.62441	validation_1-mlogloss:1.33781
# [217]	validation_0-mlogloss:0.62206	validation_1-mlogloss:1.33687
# [218]	validation_0-mlogloss:0.62005	validation_1-mlogloss:1.33598
# [219]	validation_0-mlogloss:0.61830	validation_1-mlogloss:1.33497
# [220]	validation_0-mlogloss:0.61627	validation_1-mlogloss:1.33444
# [221]	validation_0-mlogloss:0.61416	validation_1-mlogloss:1.33360
# [222]	validation_0-mlogloss:0.61223	validation_1-mlogloss:1.33259
# [223]	validation_0-mlogloss:0.61031	validation_1-mlogloss:1.33200
# [224]	validation_0-mlogloss:0.60841	validation_1-mlogloss:1.33102
# [225]	validation_0-mlogloss:0.60685	validation_1-mlogloss:1.33026
# [226]	validation_0-mlogloss:0.60460	validation_1-mlogloss:1.32956
# [227]	validation_0-mlogloss:0.60265	validation_1-mlogloss:1.32890
# [228]	validation_0-mlogloss:0.60053	validation_1-mlogloss:1.32788
# [229]	validation_0-mlogloss:0.59843	validation_1-mlogloss:1.32684
# [230]	validation_0-mlogloss:0.59656	validation_1-mlogloss:1.32617
# [231]	validation_0-mlogloss:0.59456	validation_1-mlogloss:1.32525
# [232]	validation_0-mlogloss:0.59274	validation_1-mlogloss:1.32480
# [233]	validation_0-mlogloss:0.59094	validation_1-mlogloss:1.32408
# [234]	validation_0-mlogloss:0.58923	validation_1-mlogloss:1.32338
# [235]	validation_0-mlogloss:0.58758	validation_1-mlogloss:1.32287
# [236]	validation_0-mlogloss:0.58568	validation_1-mlogloss:1.32228
# [237]	validation_0-mlogloss:0.58376	validation_1-mlogloss:1.32158
# [238]	validation_0-mlogloss:0.58183	validation_1-mlogloss:1.32048
# [239]	validation_0-mlogloss:0.58024	validation_1-mlogloss:1.31981
# [240]	validation_0-mlogloss:0.57799	validation_1-mlogloss:1.31901
# [241]	validation_0-mlogloss:0.57636	validation_1-mlogloss:1.31848
# [242]	validation_0-mlogloss:0.57458	validation_1-mlogloss:1.31769
# [243]	validation_0-mlogloss:0.57288	validation_1-mlogloss:1.31672
# [244]	validation_0-mlogloss:0.57113	validation_1-mlogloss:1.31606
# [245]	validation_0-mlogloss:0.56953	validation_1-mlogloss:1.31574
# [246]	validation_0-mlogloss:0.56797	validation_1-mlogloss:1.31496
# [247]	validation_0-mlogloss:0.56627	validation_1-mlogloss:1.31447
# [248]	validation_0-mlogloss:0.56447	validation_1-mlogloss:1.31372
# [249]	validation_0-mlogloss:0.56269	validation_1-mlogloss:1.31315
# [250]	validation_0-mlogloss:0.56082	validation_1-mlogloss:1.31253
# [251]	validation_0-mlogloss:0.55907	validation_1-mlogloss:1.31163
# [252]	validation_0-mlogloss:0.55702	validation_1-mlogloss:1.31068
# [253]	validation_0-mlogloss:0.55547	validation_1-mlogloss:1.30986
# [254]	validation_0-mlogloss:0.55367	validation_1-mlogloss:1.30907
# [255]	validation_0-mlogloss:0.55199	validation_1-mlogloss:1.30846
# [256]	validation_0-mlogloss:0.55017	validation_1-mlogloss:1.30781
# [257]	validation_0-mlogloss:0.54835	validation_1-mlogloss:1.30699
# [258]	validation_0-mlogloss:0.54644	validation_1-mlogloss:1.30639
# [259]	validation_0-mlogloss:0.54435	validation_1-mlogloss:1.30540
# [260]	validation_0-mlogloss:0.54272	validation_1-mlogloss:1.30486
# [261]	validation_0-mlogloss:0.54110	validation_1-mlogloss:1.30429
# [262]	validation_0-mlogloss:0.53940	validation_1-mlogloss:1.30351
# [263]	validation_0-mlogloss:0.53753	validation_1-mlogloss:1.30274
# [264]	validation_0-mlogloss:0.53561	validation_1-mlogloss:1.30191
# [265]	validation_0-mlogloss:0.53406	validation_1-mlogloss:1.30141
# [266]	validation_0-mlogloss:0.53217	validation_1-mlogloss:1.30072
# [267]	validation_0-mlogloss:0.53059	validation_1-mlogloss:1.30010
# [268]	validation_0-mlogloss:0.52898	validation_1-mlogloss:1.29947
# [269]	validation_0-mlogloss:0.52716	validation_1-mlogloss:1.29899
# [270]	validation_0-mlogloss:0.52535	validation_1-mlogloss:1.29837
# [271]	validation_0-mlogloss:0.52382	validation_1-mlogloss:1.29779
# [272]	validation_0-mlogloss:0.52230	validation_1-mlogloss:1.29744
# [273]	validation_0-mlogloss:0.52042	validation_1-mlogloss:1.29676
# [274]	validation_0-mlogloss:0.51900	validation_1-mlogloss:1.29604
# [275]	validation_0-mlogloss:0.51751	validation_1-mlogloss:1.29530
# [276]	validation_0-mlogloss:0.51578	validation_1-mlogloss:1.29469
# [277]	validation_0-mlogloss:0.51425	validation_1-mlogloss:1.29423
# [278]	validation_0-mlogloss:0.51273	validation_1-mlogloss:1.29356
# [279]	validation_0-mlogloss:0.51130	validation_1-mlogloss:1.29298
# [280]	validation_0-mlogloss:0.50974	validation_1-mlogloss:1.29219
# [281]	validation_0-mlogloss:0.50821	validation_1-mlogloss:1.29152
# [282]	validation_0-mlogloss:0.50646	validation_1-mlogloss:1.29069
# [283]	validation_0-mlogloss:0.50501	validation_1-mlogloss:1.29037
# [284]	validation_0-mlogloss:0.50342	validation_1-mlogloss:1.29009
# [285]	validation_0-mlogloss:0.50193	validation_1-mlogloss:1.28953
# [286]	validation_0-mlogloss:0.50049	validation_1-mlogloss:1.28893
# [287]	validation_0-mlogloss:0.49914	validation_1-mlogloss:1.28849
# [288]	validation_0-mlogloss:0.49760	validation_1-mlogloss:1.28787
# [289]	validation_0-mlogloss:0.49615	validation_1-mlogloss:1.28759
# [290]	validation_0-mlogloss:0.49448	validation_1-mlogloss:1.28712
# [291]	validation_0-mlogloss:0.49291	validation_1-mlogloss:1.28619
# [292]	validation_0-mlogloss:0.49125	validation_1-mlogloss:1.28556
# [293]	validation_0-mlogloss:0.48988	validation_1-mlogloss:1.28489
# [294]	validation_0-mlogloss:0.48848	validation_1-mlogloss:1.28435
# [295]	validation_0-mlogloss:0.48707	validation_1-mlogloss:1.28376
# [296]	validation_0-mlogloss:0.48591	validation_1-mlogloss:1.28339
# [297]	validation_0-mlogloss:0.48458	validation_1-mlogloss:1.28285
# [298]	validation_0-mlogloss:0.48344	validation_1-mlogloss:1.28268
# [299]	validation_0-mlogloss:0.48196	validation_1-mlogloss:1.28208
# Training set performance:
# Accuracy:  0.95796875
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       908
#            1       0.98      1.00      0.99       860
#            2       0.97      1.00      0.98       884
#            3       0.94      1.00      0.97       892
#            4       0.97      0.99      0.98       863
#            5       0.00      0.00      0.00        67
#            6       1.00      0.02      0.05       172
#            7       0.95      1.00      0.97       881
#            8       0.94      0.99      0.96       873
#
#     accuracy                           0.96      6400
#    macro avg       0.86      0.78      0.76      6400
# weighted avg       0.95      0.96      0.94      6400
#
# Confusion Matrix:
#  [[905   0   0   1   0   0   0   1   1]
#  [  1 856   0   1   0   0   0   2   0]
#  [  0   1 881   2   0   0   0   0   0]
#  [  1   0   0 891   0   0   0   0   0]
#  [  1   0   0   6 855   0   0   1   0]
#  [  6   6   7   7  13   0   0  20   8]
#  [ 24  10  20  29  15   0   4  27  43]
#  [  2   0   0   0   0   0   0 879   0]
#  [  3   0   2   8   0   0   0   0 860]]
# Test set performance:
# Accuracy:  0.5933791380387258
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.67      0.73      0.70       193
#            1       0.71      0.73      0.72       241
#            2       0.60      0.67      0.63       217
#            3       0.65      0.85      0.73       209
#            4       0.57      0.53      0.55       238
#            5       0.00      0.00      0.00        13
#            6       0.00      0.00      0.00        42
#            7       0.51      0.55      0.53       220
#            8       0.38      0.28      0.32       228
#
#     accuracy                           0.59      1601
#    macro avg       0.45      0.48      0.46      1601
# weighted avg       0.56      0.59      0.57      1601
#
# Confusion Matrix:
#  [[141   4   3   2  22   0   0   9  12]
#  [  2 175  25  17   4   0   0  12   6]
#  [ 11  17 146   7   7   0   0  17  12]
#  [  1   5   4 177   6   0   0  12   4]
#  [ 26   4  15  15 126   0   0  23  29]
#  [  0   4   1   1   3   0   0   4   0]
#  [  6   6   2   3   5   0   0   5  15]
#  [  7   5  14  22  23   0   0 122  27]
#  [ 18  25  35  30  24   0   0  33  63]]
# Model saved to ../data/model/best_xgboost_model_without_early_stop.pkl
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import xgboost as xgb
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Ensure sample_weights is correctly defined
# sample_weights = np.array(...)  # Replace with your actual weights

# Define a simplified parameter grid
param_grid = {
    'max_depth': [5, 7],
    'learning_rate': [0.01, 0.1],
    'n_estimators': [100, 200],
    'booster': ['gbtree'],
    'colsample_bytree': [0.3, 0.7],
    'subsample': [0.5, 0.8]
}

# Split the training data into training and validation sets
X_train_split, X_valid, y_train_split, y_valid, sample_weights_split, sample_weights_valid = train_test_split(
    combined_x_train, y_train, sample_weights, test_size=0.2, random_state=42
)

# Check if the sample weights match the training data
assert len(X_train_split) == len(y_train_split) == len(sample_weights_split), "Mismatch in training data and sample weights"

# Initialize XGBClassifier
xgb_classifier = xgb.XGBClassifier(
    objective='multi:softprob',
    num_class=len(np.unique(y_train)),
    n_jobs=10,
    random_state=42
)

# Initialize GridSearchCV with error_score='raise'
grid_search = GridSearchCV(
    estimator=xgb_classifier,
    param_grid=param_grid,
    cv=3,
    scoring='accuracy',
    verbose=1,
    error_score='raise'
)

# Fit the model with early stopping
try:
    grid_search.fit(
        X_train_split, y_train_split,
        sample_weight=sample_weights_split,
        eval_set=[(X_valid, y_valid)],
        early_stopping_rounds=10,
        verbose=True
    )

    # Get the best parameters and best model
    best_params = grid_search.best_params_
    print("Best parameters found: ", best_params)

    best_model = grid_search.best_estimator_

    # Evaluate on the training set
    train_predictions = best_model.predict(combined_x_train)
    train_accuracy = accuracy_score(y_train, train_predictions)
    train_classification_report = classification_report(y_train, train_predictions)
    train_confusion_matrix = confusion_matrix(y_train, train_predictions)

    print("Training set performance:")
    print("Accuracy: ", train_accuracy)
    print("Classification Report:\n", train_classification_report)
    print("Confusion Matrix:\n", train_confusion_matrix)

    # Evaluate on the test set
    test_predictions = best_model.predict(combined_x_test)
    test_accuracy = accuracy_score(y_test, test_predictions)
    test_classification_report = classification_report(y_test, test_predictions)
    test_confusion_matrix = confusion_matrix(y_test, test_predictions)

    print("Test set performance:")
    print("Accuracy: ", test_accuracy)
    print("Classification Report:\n", test_classification_report)
    print("Confusion Matrix:\n", test_confusion_matrix)

    # Extract evaluation results
    results = best_model.evals_result()

    # Plot the results
    epochs = len(results['validation_0']['mlogloss'])
    x_axis = range(0, epochs)

    fig, ax = plt.subplots()
    ax.plot(x_axis, results['validation_0']['mlogloss'], label='Train')
    ax.plot(x_axis, results['validation_1']['mlogloss'], label='Validation')
    ax.legend()
    plt.xlabel('Boosting Rounds')
    plt.ylabel('Log Loss')
    plt.title('XGBoost Log Loss')
    plt.show()

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Fitting 3 folds for each of 32 candidates, totalling 96 fits
# [0]	validation_0-mlogloss:2.19313
# [1]	validation_0-mlogloss:2.18920
# [2]	validation_0-mlogloss:2.18505
# [3]	validation_0-mlogloss:2.18086
# [4]	validation_0-mlogloss:2.17680
# [5]	validation_0-mlogloss:2.17268
# [6]	validation_0-mlogloss:2.16899
# [7]	validation_0-mlogloss:2.16521
# [8]	validation_0-mlogloss:2.16121
# [9]	validation_0-mlogloss:2.15758
# [10]	validation_0-mlogloss:2.15364
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [11]	validation_0-mlogloss:2.14997
# [12]	validation_0-mlogloss:2.14612
# [13]	validation_0-mlogloss:2.14272
# [14]	validation_0-mlogloss:2.13910
# [15]	validation_0-mlogloss:2.13537
# [16]	validation_0-mlogloss:2.13168
# [17]	validation_0-mlogloss:2.12800
# [18]	validation_0-mlogloss:2.12439
# [19]	validation_0-mlogloss:2.12111
# [20]	validation_0-mlogloss:2.11793
# [21]	validation_0-mlogloss:2.11450
# [22]	validation_0-mlogloss:2.11136
# [23]	validation_0-mlogloss:2.10839
# [24]	validation_0-mlogloss:2.10514
# [25]	validation_0-mlogloss:2.10202
# [26]	validation_0-mlogloss:2.09897
# [27]	validation_0-mlogloss:2.09617
# [28]	validation_0-mlogloss:2.09307
# [29]	validation_0-mlogloss:2.08991
# [30]	validation_0-mlogloss:2.08679
# [31]	validation_0-mlogloss:2.08360
# [32]	validation_0-mlogloss:2.08053
# [33]	validation_0-mlogloss:2.07752
# [34]	validation_0-mlogloss:2.07465
# [35]	validation_0-mlogloss:2.07183
# [36]	validation_0-mlogloss:2.06909
# [37]	validation_0-mlogloss:2.06610
# [38]	validation_0-mlogloss:2.06322
# [39]	validation_0-mlogloss:2.06042
# [40]	validation_0-mlogloss:2.05749
# [41]	validation_0-mlogloss:2.05444
# [42]	validation_0-mlogloss:2.05183
# [43]	validation_0-mlogloss:2.04907
# [44]	validation_0-mlogloss:2.04649
# [45]	validation_0-mlogloss:2.04397
# [46]	validation_0-mlogloss:2.04126
# [47]	validation_0-mlogloss:2.03848
# [48]	validation_0-mlogloss:2.03600
# [49]	validation_0-mlogloss:2.03329
# [50]	validation_0-mlogloss:2.03084
# [51]	validation_0-mlogloss:2.02832
# [52]	validation_0-mlogloss:2.02584
# [53]	validation_0-mlogloss:2.02318
# [54]	validation_0-mlogloss:2.02074
# [55]	validation_0-mlogloss:2.01838
# [56]	validation_0-mlogloss:2.01591
# [57]	validation_0-mlogloss:2.01366
# [58]	validation_0-mlogloss:2.01131
# [59]	validation_0-mlogloss:2.00905
# [60]	validation_0-mlogloss:2.00693
# [61]	validation_0-mlogloss:2.00449
# [62]	validation_0-mlogloss:2.00244
# [63]	validation_0-mlogloss:2.00012
# [64]	validation_0-mlogloss:1.99801
# [65]	validation_0-mlogloss:1.99575
# [66]	validation_0-mlogloss:1.99347
# [67]	validation_0-mlogloss:1.99135
# [68]	validation_0-mlogloss:1.98928
# [69]	validation_0-mlogloss:1.98713
# [70]	validation_0-mlogloss:1.98509
# [71]	validation_0-mlogloss:1.98292
# [72]	validation_0-mlogloss:1.98084
# [73]	validation_0-mlogloss:1.97894
# [74]	validation_0-mlogloss:1.97686
# [75]	validation_0-mlogloss:1.97468
# [76]	validation_0-mlogloss:1.97268
# [77]	validation_0-mlogloss:1.97067
# [78]	validation_0-mlogloss:1.96872
# [79]	validation_0-mlogloss:1.96689
# [80]	validation_0-mlogloss:1.96495
# [81]	validation_0-mlogloss:1.96303
# [82]	validation_0-mlogloss:1.96091
# [83]	validation_0-mlogloss:1.95905
# [84]	validation_0-mlogloss:1.95704
# [85]	validation_0-mlogloss:1.95500
# [86]	validation_0-mlogloss:1.95310
# [87]	validation_0-mlogloss:1.95117
# [88]	validation_0-mlogloss:1.94930
# [89]	validation_0-mlogloss:1.94757
# [90]	validation_0-mlogloss:1.94589
# [91]	validation_0-mlogloss:1.94406
# [92]	validation_0-mlogloss:1.94226
# [93]	validation_0-mlogloss:1.94038
# [94]	validation_0-mlogloss:1.93865
# [95]	validation_0-mlogloss:1.93695
# [96]	validation_0-mlogloss:1.93527
# [97]	validation_0-mlogloss:1.93353
# [98]	validation_0-mlogloss:1.93171
# [99]	validation_0-mlogloss:1.93003
# [0]	validation_0-mlogloss:2.19317
# [1]	validation_0-mlogloss:2.18899
# [2]	validation_0-mlogloss:2.18487
# [3]	validation_0-mlogloss:2.18070
# [4]	validation_0-mlogloss:2.17682
# [5]	validation_0-mlogloss:2.17284
# [6]	validation_0-mlogloss:2.16895
# [7]	validation_0-mlogloss:2.16504
# [8]	validation_0-mlogloss:2.16085
# [9]	validation_0-mlogloss:2.15708
# [10]	validation_0-mlogloss:2.15325
# [11]	validation_0-mlogloss:2.14950
# [12]	validation_0-mlogloss:2.14550
# [13]	validation_0-mlogloss:2.14194
# [14]	validation_0-mlogloss:2.13823
# [15]	validation_0-mlogloss:2.13464
# [16]	validation_0-mlogloss:2.13075
# [17]	validation_0-mlogloss:2.12711
# [18]	validation_0-mlogloss:2.12353
# [19]	validation_0-mlogloss:2.12024
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [20]	validation_0-mlogloss:2.11686
# [21]	validation_0-mlogloss:2.11357
# [22]	validation_0-mlogloss:2.11044
# [23]	validation_0-mlogloss:2.10731
# [24]	validation_0-mlogloss:2.10409
# [25]	validation_0-mlogloss:2.10095
# [26]	validation_0-mlogloss:2.09784
# [27]	validation_0-mlogloss:2.09468
# [28]	validation_0-mlogloss:2.09166
# [29]	validation_0-mlogloss:2.08866
# [30]	validation_0-mlogloss:2.08557
# [31]	validation_0-mlogloss:2.08229
# [32]	validation_0-mlogloss:2.07936
# [33]	validation_0-mlogloss:2.07636
# [34]	validation_0-mlogloss:2.07350
# [35]	validation_0-mlogloss:2.07071
# [36]	validation_0-mlogloss:2.06790
# [37]	validation_0-mlogloss:2.06506
# [38]	validation_0-mlogloss:2.06198
# [39]	validation_0-mlogloss:2.05928
# [40]	validation_0-mlogloss:2.05625
# [41]	validation_0-mlogloss:2.05329
# [42]	validation_0-mlogloss:2.05067
# [43]	validation_0-mlogloss:2.04776
# [44]	validation_0-mlogloss:2.04501
# [45]	validation_0-mlogloss:2.04233
# [46]	validation_0-mlogloss:2.03975
# [47]	validation_0-mlogloss:2.03692
# [48]	validation_0-mlogloss:2.03433
# [49]	validation_0-mlogloss:2.03184
# [50]	validation_0-mlogloss:2.02936
# [51]	validation_0-mlogloss:2.02668
# [52]	validation_0-mlogloss:2.02432
# [53]	validation_0-mlogloss:2.02186
# [54]	validation_0-mlogloss:2.01955
# [55]	validation_0-mlogloss:2.01700
# [56]	validation_0-mlogloss:2.01446
# [57]	validation_0-mlogloss:2.01222
# [58]	validation_0-mlogloss:2.00990
# [59]	validation_0-mlogloss:2.00769
# [60]	validation_0-mlogloss:2.00542
# [61]	validation_0-mlogloss:2.00323
# [62]	validation_0-mlogloss:2.00137
# [63]	validation_0-mlogloss:1.99910
# [64]	validation_0-mlogloss:1.99683
# [65]	validation_0-mlogloss:1.99470
# [66]	validation_0-mlogloss:1.99243
# [67]	validation_0-mlogloss:1.99024
# [68]	validation_0-mlogloss:1.98832
# [69]	validation_0-mlogloss:1.98617
# [70]	validation_0-mlogloss:1.98409
# [71]	validation_0-mlogloss:1.98183
# [72]	validation_0-mlogloss:1.97972
# [73]	validation_0-mlogloss:1.97773
# [74]	validation_0-mlogloss:1.97569
# [75]	validation_0-mlogloss:1.97358
# [76]	validation_0-mlogloss:1.97145
# [77]	validation_0-mlogloss:1.96939
# [78]	validation_0-mlogloss:1.96744
# [79]	validation_0-mlogloss:1.96528
# [80]	validation_0-mlogloss:1.96340
# [81]	validation_0-mlogloss:1.96161
# [82]	validation_0-mlogloss:1.95959
# [83]	validation_0-mlogloss:1.95766
# [84]	validation_0-mlogloss:1.95563
# [85]	validation_0-mlogloss:1.95370
# [86]	validation_0-mlogloss:1.95156
# [87]	validation_0-mlogloss:1.94969
# [88]	validation_0-mlogloss:1.94786
# [89]	validation_0-mlogloss:1.94596
# [90]	validation_0-mlogloss:1.94431
# [91]	validation_0-mlogloss:1.94260
# [92]	validation_0-mlogloss:1.94080
# [93]	validation_0-mlogloss:1.93891
# [94]	validation_0-mlogloss:1.93721
# [95]	validation_0-mlogloss:1.93551
# [96]	validation_0-mlogloss:1.93380
# [97]	validation_0-mlogloss:1.93203
# [98]	validation_0-mlogloss:1.93032
# [99]	validation_0-mlogloss:1.92856
# [0]	validation_0-mlogloss:2.19287
# [1]	validation_0-mlogloss:2.18860
# [2]	validation_0-mlogloss:2.18430
# [3]	validation_0-mlogloss:2.18024
# [4]	validation_0-mlogloss:2.17607
# [5]	validation_0-mlogloss:2.17198
# [6]	validation_0-mlogloss:2.16824
# [7]	validation_0-mlogloss:2.16432
# [8]	validation_0-mlogloss:2.15985
# [9]	validation_0-mlogloss:2.15577
# [10]	validation_0-mlogloss:2.15190
# [11]	validation_0-mlogloss:2.14825
# [12]	validation_0-mlogloss:2.14442
# [13]	validation_0-mlogloss:2.14107
# [14]	validation_0-mlogloss:2.13710
# [15]	validation_0-mlogloss:2.13338
# [16]	validation_0-mlogloss:2.12940
# [17]	validation_0-mlogloss:2.12588
# [18]	validation_0-mlogloss:2.12265
# [19]	validation_0-mlogloss:2.11905
# [20]	validation_0-mlogloss:2.11562
# [21]	validation_0-mlogloss:2.11215
# [22]	validation_0-mlogloss:2.10888
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [23]	validation_0-mlogloss:2.10564
# [24]	validation_0-mlogloss:2.10213
# [25]	validation_0-mlogloss:2.09878
# [26]	validation_0-mlogloss:2.09590
# [27]	validation_0-mlogloss:2.09287
# [28]	validation_0-mlogloss:2.08978
# [29]	validation_0-mlogloss:2.08707
# [30]	validation_0-mlogloss:2.08383
# [31]	validation_0-mlogloss:2.08066
# [32]	validation_0-mlogloss:2.07755
# [33]	validation_0-mlogloss:2.07463
# [34]	validation_0-mlogloss:2.07162
# [35]	validation_0-mlogloss:2.06874
# [36]	validation_0-mlogloss:2.06600
# [37]	validation_0-mlogloss:2.06317
# [38]	validation_0-mlogloss:2.06027
# [39]	validation_0-mlogloss:2.05730
# [40]	validation_0-mlogloss:2.05444
# [41]	validation_0-mlogloss:2.05158
# [42]	validation_0-mlogloss:2.04886
# [43]	validation_0-mlogloss:2.04608
# [44]	validation_0-mlogloss:2.04334
# [45]	validation_0-mlogloss:2.04073
# [46]	validation_0-mlogloss:2.03806
# [47]	validation_0-mlogloss:2.03539
# [48]	validation_0-mlogloss:2.03282
# [49]	validation_0-mlogloss:2.03048
# [50]	validation_0-mlogloss:2.02806
# [51]	validation_0-mlogloss:2.02550
# [52]	validation_0-mlogloss:2.02318
# [53]	validation_0-mlogloss:2.02078
# [54]	validation_0-mlogloss:2.01854
# [55]	validation_0-mlogloss:2.01613
# [56]	validation_0-mlogloss:2.01360
# [57]	validation_0-mlogloss:2.01113
# [58]	validation_0-mlogloss:2.00877
# [59]	validation_0-mlogloss:2.00655
# [60]	validation_0-mlogloss:2.00425
# [61]	validation_0-mlogloss:2.00184
# [62]	validation_0-mlogloss:1.99978
# [63]	validation_0-mlogloss:1.99763
# [64]	validation_0-mlogloss:1.99530
# [65]	validation_0-mlogloss:1.99297
# [66]	validation_0-mlogloss:1.99072
# [67]	validation_0-mlogloss:1.98855
# [68]	validation_0-mlogloss:1.98629
# [69]	validation_0-mlogloss:1.98417
# [70]	validation_0-mlogloss:1.98217
# [71]	validation_0-mlogloss:1.97991
# [72]	validation_0-mlogloss:1.97786
# [73]	validation_0-mlogloss:1.97588
# [74]	validation_0-mlogloss:1.97377
# [75]	validation_0-mlogloss:1.97164
# [76]	validation_0-mlogloss:1.96946
# [77]	validation_0-mlogloss:1.96743
# [78]	validation_0-mlogloss:1.96538
# [79]	validation_0-mlogloss:1.96338
# [80]	validation_0-mlogloss:1.96137
# [81]	validation_0-mlogloss:1.95951
# [82]	validation_0-mlogloss:1.95760
# [83]	validation_0-mlogloss:1.95558
# [84]	validation_0-mlogloss:1.95337
# [85]	validation_0-mlogloss:1.95139
# [86]	validation_0-mlogloss:1.94940
# [87]	validation_0-mlogloss:1.94755
# [88]	validation_0-mlogloss:1.94567
# [89]	validation_0-mlogloss:1.94389
# [90]	validation_0-mlogloss:1.94202
# [91]	validation_0-mlogloss:1.94024
# [92]	validation_0-mlogloss:1.93842
# [93]	validation_0-mlogloss:1.93635
# [94]	validation_0-mlogloss:1.93464
# [95]	validation_0-mlogloss:1.93287
# [96]	validation_0-mlogloss:1.93117
# [97]	validation_0-mlogloss:1.92943
# [98]	validation_0-mlogloss:1.92770
# [99]	validation_0-mlogloss:1.92604
# [0]	validation_0-mlogloss:2.19265
# [1]	validation_0-mlogloss:2.18817
# [2]	validation_0-mlogloss:2.18362
# [3]	validation_0-mlogloss:2.17926
# [4]	validation_0-mlogloss:2.17498
# [5]	validation_0-mlogloss:2.17082
# [6]	validation_0-mlogloss:2.16677
# [7]	validation_0-mlogloss:2.16257
# [8]	validation_0-mlogloss:2.15819
# [9]	validation_0-mlogloss:2.15419
# [10]	validation_0-mlogloss:2.15003
# [11]	validation_0-mlogloss:2.14608
# [12]	validation_0-mlogloss:2.14195
# [13]	validation_0-mlogloss:2.13826
# [14]	validation_0-mlogloss:2.13436
# [15]	validation_0-mlogloss:2.13074
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [16]	validation_0-mlogloss:2.12671
# [17]	validation_0-mlogloss:2.12300
# [18]	validation_0-mlogloss:2.11941
# [19]	validation_0-mlogloss:2.11593
# [20]	validation_0-mlogloss:2.11254
# [21]	validation_0-mlogloss:2.10898
# [22]	validation_0-mlogloss:2.10558
# [23]	validation_0-mlogloss:2.10232
# [24]	validation_0-mlogloss:2.09899
# [25]	validation_0-mlogloss:2.09570
# [26]	validation_0-mlogloss:2.09242
# [27]	validation_0-mlogloss:2.08937
# [28]	validation_0-mlogloss:2.08600
# [29]	validation_0-mlogloss:2.08289
# [30]	validation_0-mlogloss:2.07964
# [31]	validation_0-mlogloss:2.07628
# [32]	validation_0-mlogloss:2.07316
# [33]	validation_0-mlogloss:2.06986
# [34]	validation_0-mlogloss:2.06691
# [35]	validation_0-mlogloss:2.06393
# [36]	validation_0-mlogloss:2.06112
# [37]	validation_0-mlogloss:2.05802
# [38]	validation_0-mlogloss:2.05506
# [39]	validation_0-mlogloss:2.05208
# [40]	validation_0-mlogloss:2.04909
# [41]	validation_0-mlogloss:2.04606
# [42]	validation_0-mlogloss:2.04319
# [43]	validation_0-mlogloss:2.04040
# [44]	validation_0-mlogloss:2.03764
# [45]	validation_0-mlogloss:2.03503
# [46]	validation_0-mlogloss:2.03229
# [47]	validation_0-mlogloss:2.02951
# [48]	validation_0-mlogloss:2.02691
# [49]	validation_0-mlogloss:2.02422
# [50]	validation_0-mlogloss:2.02160
# [51]	validation_0-mlogloss:2.01878
# [52]	validation_0-mlogloss:2.01631
# [53]	validation_0-mlogloss:2.01373
# [54]	validation_0-mlogloss:2.01113
# [55]	validation_0-mlogloss:2.00849
# [56]	validation_0-mlogloss:2.00594
# [57]	validation_0-mlogloss:2.00343
# [58]	validation_0-mlogloss:2.00109
# [59]	validation_0-mlogloss:1.99872
# [60]	validation_0-mlogloss:1.99644
# [61]	validation_0-mlogloss:1.99406
# [62]	validation_0-mlogloss:1.99209
# [63]	validation_0-mlogloss:1.98980
# [64]	validation_0-mlogloss:1.98739
# [65]	validation_0-mlogloss:1.98515
# [66]	validation_0-mlogloss:1.98280
# [67]	validation_0-mlogloss:1.98037
# [68]	validation_0-mlogloss:1.97816
# [69]	validation_0-mlogloss:1.97589
# [70]	validation_0-mlogloss:1.97375
# [71]	validation_0-mlogloss:1.97145
# [72]	validation_0-mlogloss:1.96919
# [73]	validation_0-mlogloss:1.96732
# [74]	validation_0-mlogloss:1.96525
# [75]	validation_0-mlogloss:1.96300
# [76]	validation_0-mlogloss:1.96069
# [77]	validation_0-mlogloss:1.95852
# [78]	validation_0-mlogloss:1.95648
# [79]	validation_0-mlogloss:1.95438
# [80]	validation_0-mlogloss:1.95237
# [81]	validation_0-mlogloss:1.95048
# [82]	validation_0-mlogloss:1.94829
# [83]	validation_0-mlogloss:1.94645
# [84]	validation_0-mlogloss:1.94425
# [85]	validation_0-mlogloss:1.94218
# [86]	validation_0-mlogloss:1.94027
# [87]	validation_0-mlogloss:1.93836
# [88]	validation_0-mlogloss:1.93639
# [89]	validation_0-mlogloss:1.93455
# [90]	validation_0-mlogloss:1.93280
# [91]	validation_0-mlogloss:1.93086
# [92]	validation_0-mlogloss:1.92908
# [93]	validation_0-mlogloss:1.92709
# [94]	validation_0-mlogloss:1.92523
# [95]	validation_0-mlogloss:1.92335
# [96]	validation_0-mlogloss:1.92166
# [97]	validation_0-mlogloss:1.91992
# [98]	validation_0-mlogloss:1.91814
# [99]	validation_0-mlogloss:1.91641
# [0]	validation_0-mlogloss:2.19267
# [1]	validation_0-mlogloss:2.18818
# [2]	validation_0-mlogloss:2.18370
# [3]	validation_0-mlogloss:2.17938
# [4]	validation_0-mlogloss:2.17506
# [5]	validation_0-mlogloss:2.17063
# [6]	validation_0-mlogloss:2.16660
# [7]	validation_0-mlogloss:2.16237
# [8]	validation_0-mlogloss:2.15792
# [9]	validation_0-mlogloss:2.15381
# [10]	validation_0-mlogloss:2.14984
# [11]	validation_0-mlogloss:2.14580
# [12]	validation_0-mlogloss:2.14157
# [13]	validation_0-mlogloss:2.13770
# [14]	validation_0-mlogloss:2.13365
# [15]	validation_0-mlogloss:2.13003
# [16]	validation_0-mlogloss:2.12597
# [17]	validation_0-mlogloss:2.12228
# [18]	validation_0-mlogloss:2.11879
# [19]	validation_0-mlogloss:2.11528
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [20]	validation_0-mlogloss:2.11189
# [21]	validation_0-mlogloss:2.10834
# [22]	validation_0-mlogloss:2.10501
# [23]	validation_0-mlogloss:2.10167
# [24]	validation_0-mlogloss:2.09802
# [25]	validation_0-mlogloss:2.09459
# [26]	validation_0-mlogloss:2.09139
# [27]	validation_0-mlogloss:2.08816
# [28]	validation_0-mlogloss:2.08490
# [29]	validation_0-mlogloss:2.08197
# [30]	validation_0-mlogloss:2.07862
# [31]	validation_0-mlogloss:2.07527
# [32]	validation_0-mlogloss:2.07221
# [33]	validation_0-mlogloss:2.06889
# [34]	validation_0-mlogloss:2.06568
# [35]	validation_0-mlogloss:2.06248
# [36]	validation_0-mlogloss:2.05951
# [37]	validation_0-mlogloss:2.05654
# [38]	validation_0-mlogloss:2.05342
# [39]	validation_0-mlogloss:2.05055
# [40]	validation_0-mlogloss:2.04753
# [41]	validation_0-mlogloss:2.04456
# [42]	validation_0-mlogloss:2.04179
# [43]	validation_0-mlogloss:2.03890
# [44]	validation_0-mlogloss:2.03578
# [45]	validation_0-mlogloss:2.03297
# [46]	validation_0-mlogloss:2.03034
# [47]	validation_0-mlogloss:2.02744
# [48]	validation_0-mlogloss:2.02475
# [49]	validation_0-mlogloss:2.02215
# [50]	validation_0-mlogloss:2.01955
# [51]	validation_0-mlogloss:2.01665
# [52]	validation_0-mlogloss:2.01421
# [53]	validation_0-mlogloss:2.01163
# [54]	validation_0-mlogloss:2.00911
# [55]	validation_0-mlogloss:2.00664
# [56]	validation_0-mlogloss:2.00404
# [57]	validation_0-mlogloss:2.00184
# [58]	validation_0-mlogloss:1.99942
# [59]	validation_0-mlogloss:1.99700
# [60]	validation_0-mlogloss:1.99475
# [61]	validation_0-mlogloss:1.99241
# [62]	validation_0-mlogloss:1.99026
# [63]	validation_0-mlogloss:1.98787
# [64]	validation_0-mlogloss:1.98542
# [65]	validation_0-mlogloss:1.98313
# [66]	validation_0-mlogloss:1.98087
# [67]	validation_0-mlogloss:1.97866
# [68]	validation_0-mlogloss:1.97651
# [69]	validation_0-mlogloss:1.97408
# [70]	validation_0-mlogloss:1.97186
# [71]	validation_0-mlogloss:1.96959
# [72]	validation_0-mlogloss:1.96738
# [73]	validation_0-mlogloss:1.96537
# [74]	validation_0-mlogloss:1.96327
# [75]	validation_0-mlogloss:1.96115
# [76]	validation_0-mlogloss:1.95892
# [77]	validation_0-mlogloss:1.95672
# [78]	validation_0-mlogloss:1.95453
# [79]	validation_0-mlogloss:1.95248
# [80]	validation_0-mlogloss:1.95048
# [81]	validation_0-mlogloss:1.94854
# [82]	validation_0-mlogloss:1.94642
# [83]	validation_0-mlogloss:1.94443
# [84]	validation_0-mlogloss:1.94223
# [85]	validation_0-mlogloss:1.94009
# [86]	validation_0-mlogloss:1.93802
# [87]	validation_0-mlogloss:1.93598
# [88]	validation_0-mlogloss:1.93389
# [89]	validation_0-mlogloss:1.93206
# [90]	validation_0-mlogloss:1.93017
# [91]	validation_0-mlogloss:1.92839
# [92]	validation_0-mlogloss:1.92649
# [93]	validation_0-mlogloss:1.92449
# [94]	validation_0-mlogloss:1.92269
# [95]	validation_0-mlogloss:1.92083
# [96]	validation_0-mlogloss:1.91903
# [97]	validation_0-mlogloss:1.91718
# [98]	validation_0-mlogloss:1.91536
# [99]	validation_0-mlogloss:1.91374
# [0]	validation_0-mlogloss:2.19257
# [1]	validation_0-mlogloss:2.18807
# [2]	validation_0-mlogloss:2.18347
# [3]	validation_0-mlogloss:2.17915
# [4]	validation_0-mlogloss:2.17489
# [5]	validation_0-mlogloss:2.17051
# [6]	validation_0-mlogloss:2.16631
# [7]	validation_0-mlogloss:2.16208
# [8]	validation_0-mlogloss:2.15763
# [9]	validation_0-mlogloss:2.15344
# [10]	validation_0-mlogloss:2.14944
# [11]	validation_0-mlogloss:2.14530
# [12]	validation_0-mlogloss:2.14088
# [13]	validation_0-mlogloss:2.13710
# [14]	validation_0-mlogloss:2.13309
# [15]	validation_0-mlogloss:2.12919
# [16]	validation_0-mlogloss:2.12518
# [17]	validation_0-mlogloss:2.12156
# [18]	validation_0-mlogloss:2.11794
# [19]	validation_0-mlogloss:2.11426
# [20]	validation_0-mlogloss:2.11048
# [21]	validation_0-mlogloss:2.10673
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [22]	validation_0-mlogloss:2.10318
# [23]	validation_0-mlogloss:2.09968
# [24]	validation_0-mlogloss:2.09610
# [25]	validation_0-mlogloss:2.09264
# [26]	validation_0-mlogloss:2.08949
# [27]	validation_0-mlogloss:2.08641
# [28]	validation_0-mlogloss:2.08308
# [29]	validation_0-mlogloss:2.08000
# [30]	validation_0-mlogloss:2.07687
# [31]	validation_0-mlogloss:2.07344
# [32]	validation_0-mlogloss:2.07024
# [33]	validation_0-mlogloss:2.06718
# [34]	validation_0-mlogloss:2.06414
# [35]	validation_0-mlogloss:2.06095
# [36]	validation_0-mlogloss:2.05794
# [37]	validation_0-mlogloss:2.05482
# [38]	validation_0-mlogloss:2.05169
# [39]	validation_0-mlogloss:2.04861
# [40]	validation_0-mlogloss:2.04560
# [41]	validation_0-mlogloss:2.04263
# [42]	validation_0-mlogloss:2.03971
# [43]	validation_0-mlogloss:2.03686
# [44]	validation_0-mlogloss:2.03380
# [45]	validation_0-mlogloss:2.03111
# [46]	validation_0-mlogloss:2.02837
# [47]	validation_0-mlogloss:2.02548
# [48]	validation_0-mlogloss:2.02284
# [49]	validation_0-mlogloss:2.02040
# [50]	validation_0-mlogloss:2.01777
# [51]	validation_0-mlogloss:2.01504
# [52]	validation_0-mlogloss:2.01245
# [53]	validation_0-mlogloss:2.00976
# [54]	validation_0-mlogloss:2.00741
# [55]	validation_0-mlogloss:2.00470
# [56]	validation_0-mlogloss:2.00214
# [57]	validation_0-mlogloss:1.99966
# [58]	validation_0-mlogloss:1.99728
# [59]	validation_0-mlogloss:1.99488
# [60]	validation_0-mlogloss:1.99247
# [61]	validation_0-mlogloss:1.99013
# [62]	validation_0-mlogloss:1.98793
# [63]	validation_0-mlogloss:1.98580
# [64]	validation_0-mlogloss:1.98335
# [65]	validation_0-mlogloss:1.98104
# [66]	validation_0-mlogloss:1.97848
# [67]	validation_0-mlogloss:1.97628
# [68]	validation_0-mlogloss:1.97402
# [69]	validation_0-mlogloss:1.97178
# [70]	validation_0-mlogloss:1.96952
# [71]	validation_0-mlogloss:1.96721
# [72]	validation_0-mlogloss:1.96513
# [73]	validation_0-mlogloss:1.96300
# [74]	validation_0-mlogloss:1.96077
# [75]	validation_0-mlogloss:1.95867
# [76]	validation_0-mlogloss:1.95632
# [77]	validation_0-mlogloss:1.95421
# [78]	validation_0-mlogloss:1.95211
# [79]	validation_0-mlogloss:1.95005
# [80]	validation_0-mlogloss:1.94810
# [81]	validation_0-mlogloss:1.94617
# [82]	validation_0-mlogloss:1.94416
# [83]	validation_0-mlogloss:1.94214
# [84]	validation_0-mlogloss:1.93994
# [85]	validation_0-mlogloss:1.93799
# [86]	validation_0-mlogloss:1.93589
# [87]	validation_0-mlogloss:1.93385
# [88]	validation_0-mlogloss:1.93180
# [89]	validation_0-mlogloss:1.92997
# [90]	validation_0-mlogloss:1.92803
# [91]	validation_0-mlogloss:1.92624
# [92]	validation_0-mlogloss:1.92442
# [93]	validation_0-mlogloss:1.92231
# [94]	validation_0-mlogloss:1.92051
# [95]	validation_0-mlogloss:1.91874
# [96]	validation_0-mlogloss:1.91689
# [97]	validation_0-mlogloss:1.91512
# [98]	validation_0-mlogloss:1.91338
# [99]	validation_0-mlogloss:1.91174
# [0]	validation_0-mlogloss:2.19313
# [1]	validation_0-mlogloss:2.18920
# [2]	validation_0-mlogloss:2.18505
# [3]	validation_0-mlogloss:2.18086
# [4]	validation_0-mlogloss:2.17680
# [5]	validation_0-mlogloss:2.17268
# [6]	validation_0-mlogloss:2.16899
# [7]	validation_0-mlogloss:2.16521
# [8]	validation_0-mlogloss:2.16121
# [9]	validation_0-mlogloss:2.15758
# [10]	validation_0-mlogloss:2.15364
# [11]	validation_0-mlogloss:2.14997
# [12]	validation_0-mlogloss:2.14612
# [13]	validation_0-mlogloss:2.14272
# [14]	validation_0-mlogloss:2.13910
# [15]	validation_0-mlogloss:2.13537
# [16]	validation_0-mlogloss:2.13168
# [17]	validation_0-mlogloss:2.12800
# [18]	validation_0-mlogloss:2.12439
# [19]	validation_0-mlogloss:2.12111
# [20]	validation_0-mlogloss:2.11793
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [21]	validation_0-mlogloss:2.11450
# [22]	validation_0-mlogloss:2.11136
# [23]	validation_0-mlogloss:2.10839
# [24]	validation_0-mlogloss:2.10514
# [25]	validation_0-mlogloss:2.10202
# [26]	validation_0-mlogloss:2.09897
# [27]	validation_0-mlogloss:2.09617
# [28]	validation_0-mlogloss:2.09307
# [29]	validation_0-mlogloss:2.08991
# [30]	validation_0-mlogloss:2.08679
# [31]	validation_0-mlogloss:2.08360
# [32]	validation_0-mlogloss:2.08053
# [33]	validation_0-mlogloss:2.07752
# [34]	validation_0-mlogloss:2.07465
# [35]	validation_0-mlogloss:2.07183
# [36]	validation_0-mlogloss:2.06909
# [37]	validation_0-mlogloss:2.06610
# [38]	validation_0-mlogloss:2.06322
# [39]	validation_0-mlogloss:2.06042
# [40]	validation_0-mlogloss:2.05749
# [41]	validation_0-mlogloss:2.05444
# [42]	validation_0-mlogloss:2.05183
# [43]	validation_0-mlogloss:2.04907
# [44]	validation_0-mlogloss:2.04649
# [45]	validation_0-mlogloss:2.04397
# [46]	validation_0-mlogloss:2.04126
# [47]	validation_0-mlogloss:2.03848
# [48]	validation_0-mlogloss:2.03600
# [49]	validation_0-mlogloss:2.03329
# [50]	validation_0-mlogloss:2.03084
# [51]	validation_0-mlogloss:2.02832
# [52]	validation_0-mlogloss:2.02584
# [53]	validation_0-mlogloss:2.02318
# [54]	validation_0-mlogloss:2.02074
# [55]	validation_0-mlogloss:2.01838
# [56]	validation_0-mlogloss:2.01591
# [57]	validation_0-mlogloss:2.01366
# [58]	validation_0-mlogloss:2.01131
# [59]	validation_0-mlogloss:2.00905
# [60]	validation_0-mlogloss:2.00693
# [61]	validation_0-mlogloss:2.00449
# [62]	validation_0-mlogloss:2.00244
# [63]	validation_0-mlogloss:2.00012
# [64]	validation_0-mlogloss:1.99801
# [65]	validation_0-mlogloss:1.99575
# [66]	validation_0-mlogloss:1.99347
# [67]	validation_0-mlogloss:1.99135
# [68]	validation_0-mlogloss:1.98928
# [69]	validation_0-mlogloss:1.98713
# [70]	validation_0-mlogloss:1.98509
# [71]	validation_0-mlogloss:1.98292
# [72]	validation_0-mlogloss:1.98084
# [73]	validation_0-mlogloss:1.97894
# [74]	validation_0-mlogloss:1.97686
# [75]	validation_0-mlogloss:1.97468
# [76]	validation_0-mlogloss:1.97268
# [77]	validation_0-mlogloss:1.97067
# [78]	validation_0-mlogloss:1.96872
# [79]	validation_0-mlogloss:1.96689
# [80]	validation_0-mlogloss:1.96495
# [81]	validation_0-mlogloss:1.96303
# [82]	validation_0-mlogloss:1.96091
# [83]	validation_0-mlogloss:1.95905
# [84]	validation_0-mlogloss:1.95704
# [85]	validation_0-mlogloss:1.95500
# [86]	validation_0-mlogloss:1.95310
# [87]	validation_0-mlogloss:1.95117
# [88]	validation_0-mlogloss:1.94930
# [89]	validation_0-mlogloss:1.94757
# [90]	validation_0-mlogloss:1.94589
# [91]	validation_0-mlogloss:1.94406
# [92]	validation_0-mlogloss:1.94226
# [93]	validation_0-mlogloss:1.94038
# [94]	validation_0-mlogloss:1.93865
# [95]	validation_0-mlogloss:1.93695
# [96]	validation_0-mlogloss:1.93527
# [97]	validation_0-mlogloss:1.93353
# [98]	validation_0-mlogloss:1.93171
# [99]	validation_0-mlogloss:1.93003
# [100]	validation_0-mlogloss:1.92856
# [101]	validation_0-mlogloss:1.92695
# [102]	validation_0-mlogloss:1.92521
# [103]	validation_0-mlogloss:1.92371
# [104]	validation_0-mlogloss:1.92189
# [105]	validation_0-mlogloss:1.92033
# [106]	validation_0-mlogloss:1.91874
# [107]	validation_0-mlogloss:1.91714
# [108]	validation_0-mlogloss:1.91564
# [109]	validation_0-mlogloss:1.91420
# [110]	validation_0-mlogloss:1.91273
# [111]	validation_0-mlogloss:1.91132
# [112]	validation_0-mlogloss:1.90970
# [113]	validation_0-mlogloss:1.90826
# [114]	validation_0-mlogloss:1.90673
# [115]	validation_0-mlogloss:1.90542
# [116]	validation_0-mlogloss:1.90395
# [117]	validation_0-mlogloss:1.90257
# [118]	validation_0-mlogloss:1.90126
# [119]	validation_0-mlogloss:1.89984
# [120]	validation_0-mlogloss:1.89843
# [121]	validation_0-mlogloss:1.89698
# [122]	validation_0-mlogloss:1.89564
# [123]	validation_0-mlogloss:1.89418
# [124]	validation_0-mlogloss:1.89301
# [125]	validation_0-mlogloss:1.89164
# [126]	validation_0-mlogloss:1.89052
# [127]	validation_0-mlogloss:1.88928
# [128]	validation_0-mlogloss:1.88785
# [129]	validation_0-mlogloss:1.88664
# [130]	validation_0-mlogloss:1.88521
# [131]	validation_0-mlogloss:1.88383
# [132]	validation_0-mlogloss:1.88245
# [133]	validation_0-mlogloss:1.88107
# [134]	validation_0-mlogloss:1.87976
# [135]	validation_0-mlogloss:1.87861
# [136]	validation_0-mlogloss:1.87740
# [137]	validation_0-mlogloss:1.87625
# [138]	validation_0-mlogloss:1.87499
# [139]	validation_0-mlogloss:1.87373
# [140]	validation_0-mlogloss:1.87251
# [141]	validation_0-mlogloss:1.87122
# [142]	validation_0-mlogloss:1.86976
# [143]	validation_0-mlogloss:1.86852
# [144]	validation_0-mlogloss:1.86731
# [145]	validation_0-mlogloss:1.86596
# [146]	validation_0-mlogloss:1.86470
# [147]	validation_0-mlogloss:1.86346
# [148]	validation_0-mlogloss:1.86227
# [149]	validation_0-mlogloss:1.86101
# [150]	validation_0-mlogloss:1.85990
# [151]	validation_0-mlogloss:1.85855
# [152]	validation_0-mlogloss:1.85759
# [153]	validation_0-mlogloss:1.85645
# [154]	validation_0-mlogloss:1.85527
# [155]	validation_0-mlogloss:1.85413
# [156]	validation_0-mlogloss:1.85299
# [157]	validation_0-mlogloss:1.85192
# [158]	validation_0-mlogloss:1.85077
# [159]	validation_0-mlogloss:1.84971
# [160]	validation_0-mlogloss:1.84870
# [161]	validation_0-mlogloss:1.84752
# [162]	validation_0-mlogloss:1.84652
# [163]	validation_0-mlogloss:1.84551
# [164]	validation_0-mlogloss:1.84432
# [165]	validation_0-mlogloss:1.84318
# [166]	validation_0-mlogloss:1.84214
# [167]	validation_0-mlogloss:1.84095
# [168]	validation_0-mlogloss:1.83984
# [169]	validation_0-mlogloss:1.83885
# [170]	validation_0-mlogloss:1.83781
# [171]	validation_0-mlogloss:1.83666
# [172]	validation_0-mlogloss:1.83569
# [173]	validation_0-mlogloss:1.83454
# [174]	validation_0-mlogloss:1.83330
# [175]	validation_0-mlogloss:1.83225
# [176]	validation_0-mlogloss:1.83136
# [177]	validation_0-mlogloss:1.83050
# [178]	validation_0-mlogloss:1.82943
# [179]	validation_0-mlogloss:1.82848
# [180]	validation_0-mlogloss:1.82753
# [181]	validation_0-mlogloss:1.82647
# [182]	validation_0-mlogloss:1.82558
# [183]	validation_0-mlogloss:1.82468
# [184]	validation_0-mlogloss:1.82370
# [185]	validation_0-mlogloss:1.82285
# [186]	validation_0-mlogloss:1.82194
# [187]	validation_0-mlogloss:1.82118
# [188]	validation_0-mlogloss:1.82038
# [189]	validation_0-mlogloss:1.81946
# [190]	validation_0-mlogloss:1.81850
# [191]	validation_0-mlogloss:1.81778
# [192]	validation_0-mlogloss:1.81693
# [193]	validation_0-mlogloss:1.81619
# [194]	validation_0-mlogloss:1.81525
# [195]	validation_0-mlogloss:1.81446
# [196]	validation_0-mlogloss:1.81344
# [197]	validation_0-mlogloss:1.81277
# [198]	validation_0-mlogloss:1.81214
# [199]	validation_0-mlogloss:1.81158
# [0]	validation_0-mlogloss:2.19317
# [1]	validation_0-mlogloss:2.18899
# [2]	validation_0-mlogloss:2.18487
# [3]	validation_0-mlogloss:2.18070
# [4]	validation_0-mlogloss:2.17682
# [5]	validation_0-mlogloss:2.17284
# [6]	validation_0-mlogloss:2.16895
# [7]	validation_0-mlogloss:2.16504
# [8]	validation_0-mlogloss:2.16085
# [9]	validation_0-mlogloss:2.15708
# [10]	validation_0-mlogloss:2.15325
# [11]	validation_0-mlogloss:2.14950
# [12]	validation_0-mlogloss:2.14550
# [13]	validation_0-mlogloss:2.14194
# [14]	validation_0-mlogloss:2.13823
# [15]	validation_0-mlogloss:2.13464
# [16]	validation_0-mlogloss:2.13075
# [17]	validation_0-mlogloss:2.12711
# [18]	validation_0-mlogloss:2.12353
# [19]	validation_0-mlogloss:2.12024
# [20]	validation_0-mlogloss:2.11686
# [21]	validation_0-mlogloss:2.11357
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [22]	validation_0-mlogloss:2.11044
# [23]	validation_0-mlogloss:2.10731
# [24]	validation_0-mlogloss:2.10409
# [25]	validation_0-mlogloss:2.10095
# [26]	validation_0-mlogloss:2.09784
# [27]	validation_0-mlogloss:2.09468
# [28]	validation_0-mlogloss:2.09166
# [29]	validation_0-mlogloss:2.08866
# [30]	validation_0-mlogloss:2.08557
# [31]	validation_0-mlogloss:2.08229
# [32]	validation_0-mlogloss:2.07936
# [33]	validation_0-mlogloss:2.07636
# [34]	validation_0-mlogloss:2.07350
# [35]	validation_0-mlogloss:2.07071
# [36]	validation_0-mlogloss:2.06790
# [37]	validation_0-mlogloss:2.06506
# [38]	validation_0-mlogloss:2.06198
# [39]	validation_0-mlogloss:2.05928
# [40]	validation_0-mlogloss:2.05625
# [41]	validation_0-mlogloss:2.05329
# [42]	validation_0-mlogloss:2.05067
# [43]	validation_0-mlogloss:2.04776
# [44]	validation_0-mlogloss:2.04501
# [45]	validation_0-mlogloss:2.04233
# [46]	validation_0-mlogloss:2.03975
# [47]	validation_0-mlogloss:2.03692
# [48]	validation_0-mlogloss:2.03433
# [49]	validation_0-mlogloss:2.03184
# [50]	validation_0-mlogloss:2.02936
# [51]	validation_0-mlogloss:2.02668
# [52]	validation_0-mlogloss:2.02432
# [53]	validation_0-mlogloss:2.02186
# [54]	validation_0-mlogloss:2.01955
# [55]	validation_0-mlogloss:2.01700
# [56]	validation_0-mlogloss:2.01446
# [57]	validation_0-mlogloss:2.01222
# [58]	validation_0-mlogloss:2.00990
# [59]	validation_0-mlogloss:2.00769
# [60]	validation_0-mlogloss:2.00542
# [61]	validation_0-mlogloss:2.00323
# [62]	validation_0-mlogloss:2.00137
# [63]	validation_0-mlogloss:1.99910
# [64]	validation_0-mlogloss:1.99683
# [65]	validation_0-mlogloss:1.99470
# [66]	validation_0-mlogloss:1.99243
# [67]	validation_0-mlogloss:1.99024
# [68]	validation_0-mlogloss:1.98832
# [69]	validation_0-mlogloss:1.98617
# [70]	validation_0-mlogloss:1.98409
# [71]	validation_0-mlogloss:1.98183
# [72]	validation_0-mlogloss:1.97972
# [73]	validation_0-mlogloss:1.97773
# [74]	validation_0-mlogloss:1.97569
# [75]	validation_0-mlogloss:1.97358
# [76]	validation_0-mlogloss:1.97145
# [77]	validation_0-mlogloss:1.96939
# [78]	validation_0-mlogloss:1.96744
# [79]	validation_0-mlogloss:1.96528
# [80]	validation_0-mlogloss:1.96340
# [81]	validation_0-mlogloss:1.96161
# [82]	validation_0-mlogloss:1.95959
# [83]	validation_0-mlogloss:1.95766
# [84]	validation_0-mlogloss:1.95563
# [85]	validation_0-mlogloss:1.95370
# [86]	validation_0-mlogloss:1.95156
# [87]	validation_0-mlogloss:1.94969
# [88]	validation_0-mlogloss:1.94786
# [89]	validation_0-mlogloss:1.94596
# [90]	validation_0-mlogloss:1.94431
# [91]	validation_0-mlogloss:1.94260
# [92]	validation_0-mlogloss:1.94080
# [93]	validation_0-mlogloss:1.93891
# [94]	validation_0-mlogloss:1.93721
# [95]	validation_0-mlogloss:1.93551
# [96]	validation_0-mlogloss:1.93380
# [97]	validation_0-mlogloss:1.93203
# [98]	validation_0-mlogloss:1.93032
# [99]	validation_0-mlogloss:1.92856
# [100]	validation_0-mlogloss:1.92685
# [101]	validation_0-mlogloss:1.92507
# [102]	validation_0-mlogloss:1.92335
# [103]	validation_0-mlogloss:1.92175
# [104]	validation_0-mlogloss:1.92007
# [105]	validation_0-mlogloss:1.91836
# [106]	validation_0-mlogloss:1.91680
# [107]	validation_0-mlogloss:1.91518
# [108]	validation_0-mlogloss:1.91355
# [109]	validation_0-mlogloss:1.91212
# [110]	validation_0-mlogloss:1.91051
# [111]	validation_0-mlogloss:1.90898
# [112]	validation_0-mlogloss:1.90744
# [113]	validation_0-mlogloss:1.90598
# [114]	validation_0-mlogloss:1.90450
# [115]	validation_0-mlogloss:1.90308
# [116]	validation_0-mlogloss:1.90167
# [117]	validation_0-mlogloss:1.90015
# [118]	validation_0-mlogloss:1.89878
# [119]	validation_0-mlogloss:1.89730
# [120]	validation_0-mlogloss:1.89578
# [121]	validation_0-mlogloss:1.89422
# [122]	validation_0-mlogloss:1.89273
# [123]	validation_0-mlogloss:1.89143
# [124]	validation_0-mlogloss:1.89012
# [125]	validation_0-mlogloss:1.88871
# [126]	validation_0-mlogloss:1.88748
# [127]	validation_0-mlogloss:1.88617
# [128]	validation_0-mlogloss:1.88483
# [129]	validation_0-mlogloss:1.88345
# [130]	validation_0-mlogloss:1.88204
# [131]	validation_0-mlogloss:1.88072
# [132]	validation_0-mlogloss:1.87951
# [133]	validation_0-mlogloss:1.87796
# [134]	validation_0-mlogloss:1.87648
# [135]	validation_0-mlogloss:1.87515
# [136]	validation_0-mlogloss:1.87387
# [137]	validation_0-mlogloss:1.87251
# [138]	validation_0-mlogloss:1.87131
# [139]	validation_0-mlogloss:1.86993
# [140]	validation_0-mlogloss:1.86866
# [141]	validation_0-mlogloss:1.86741
# [142]	validation_0-mlogloss:1.86622
# [143]	validation_0-mlogloss:1.86500
# [144]	validation_0-mlogloss:1.86391
# [145]	validation_0-mlogloss:1.86264
# [146]	validation_0-mlogloss:1.86143
# [147]	validation_0-mlogloss:1.86021
# [148]	validation_0-mlogloss:1.85893
# [149]	validation_0-mlogloss:1.85769
# [150]	validation_0-mlogloss:1.85661
# [151]	validation_0-mlogloss:1.85541
# [152]	validation_0-mlogloss:1.85433
# [153]	validation_0-mlogloss:1.85319
# [154]	validation_0-mlogloss:1.85190
# [155]	validation_0-mlogloss:1.85083
# [156]	validation_0-mlogloss:1.84965
# [157]	validation_0-mlogloss:1.84849
# [158]	validation_0-mlogloss:1.84741
# [159]	validation_0-mlogloss:1.84635
# [160]	validation_0-mlogloss:1.84528
# [161]	validation_0-mlogloss:1.84414
# [162]	validation_0-mlogloss:1.84303
# [163]	validation_0-mlogloss:1.84192
# [164]	validation_0-mlogloss:1.84091
# [165]	validation_0-mlogloss:1.83982
# [166]	validation_0-mlogloss:1.83885
# [167]	validation_0-mlogloss:1.83766
# [168]	validation_0-mlogloss:1.83657
# [169]	validation_0-mlogloss:1.83546
# [170]	validation_0-mlogloss:1.83437
# [171]	validation_0-mlogloss:1.83334
# [172]	validation_0-mlogloss:1.83248
# [173]	validation_0-mlogloss:1.83137
# [174]	validation_0-mlogloss:1.83040
# [175]	validation_0-mlogloss:1.82943
# [176]	validation_0-mlogloss:1.82855
# [177]	validation_0-mlogloss:1.82759
# [178]	validation_0-mlogloss:1.82662
# [179]	validation_0-mlogloss:1.82570
# [180]	validation_0-mlogloss:1.82482
# [181]	validation_0-mlogloss:1.82370
# [182]	validation_0-mlogloss:1.82270
# [183]	validation_0-mlogloss:1.82188
# [184]	validation_0-mlogloss:1.82094
# [185]	validation_0-mlogloss:1.82001
# [186]	validation_0-mlogloss:1.81909
# [187]	validation_0-mlogloss:1.81822
# [188]	validation_0-mlogloss:1.81736
# [189]	validation_0-mlogloss:1.81640
# [190]	validation_0-mlogloss:1.81544
# [191]	validation_0-mlogloss:1.81456
# [192]	validation_0-mlogloss:1.81382
# [193]	validation_0-mlogloss:1.81292
# [194]	validation_0-mlogloss:1.81194
# [195]	validation_0-mlogloss:1.81108
# [196]	validation_0-mlogloss:1.81009
# [197]	validation_0-mlogloss:1.80926
# [198]	validation_0-mlogloss:1.80857
# [199]	validation_0-mlogloss:1.80765
# [0]	validation_0-mlogloss:2.19287
# [1]	validation_0-mlogloss:2.18860
# [2]	validation_0-mlogloss:2.18430
# [3]	validation_0-mlogloss:2.18024
# [4]	validation_0-mlogloss:2.17607
# [5]	validation_0-mlogloss:2.17198
# [6]	validation_0-mlogloss:2.16824
# [7]	validation_0-mlogloss:2.16432
# [8]	validation_0-mlogloss:2.15985
# [9]	validation_0-mlogloss:2.15577
# [10]	validation_0-mlogloss:2.15190
# [11]	validation_0-mlogloss:2.14825
# [12]	validation_0-mlogloss:2.14442
# [13]	validation_0-mlogloss:2.14107
# [14]	validation_0-mlogloss:2.13710
# [15]	validation_0-mlogloss:2.13338
# [16]	validation_0-mlogloss:2.12940
# [17]	validation_0-mlogloss:2.12588
# [18]	validation_0-mlogloss:2.12265
# [19]	validation_0-mlogloss:2.11905
# [20]	validation_0-mlogloss:2.11562
# [21]	validation_0-mlogloss:2.11215
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [22]	validation_0-mlogloss:2.10888
# [23]	validation_0-mlogloss:2.10564
# [24]	validation_0-mlogloss:2.10213
# [25]	validation_0-mlogloss:2.09878
# [26]	validation_0-mlogloss:2.09590
# [27]	validation_0-mlogloss:2.09287
# [28]	validation_0-mlogloss:2.08978
# [29]	validation_0-mlogloss:2.08707
# [30]	validation_0-mlogloss:2.08383
# [31]	validation_0-mlogloss:2.08066
# [32]	validation_0-mlogloss:2.07755
# [33]	validation_0-mlogloss:2.07463
# [34]	validation_0-mlogloss:2.07162
# [35]	validation_0-mlogloss:2.06874
# [36]	validation_0-mlogloss:2.06600
# [37]	validation_0-mlogloss:2.06317
# [38]	validation_0-mlogloss:2.06027
# [39]	validation_0-mlogloss:2.05730
# [40]	validation_0-mlogloss:2.05444
# [41]	validation_0-mlogloss:2.05158
# [42]	validation_0-mlogloss:2.04886
# [43]	validation_0-mlogloss:2.04608
# [44]	validation_0-mlogloss:2.04334
# [45]	validation_0-mlogloss:2.04073
# [46]	validation_0-mlogloss:2.03806
# [47]	validation_0-mlogloss:2.03539
# [48]	validation_0-mlogloss:2.03282
# [49]	validation_0-mlogloss:2.03048
# [50]	validation_0-mlogloss:2.02806
# [51]	validation_0-mlogloss:2.02550
# [52]	validation_0-mlogloss:2.02318
# [53]	validation_0-mlogloss:2.02078
# [54]	validation_0-mlogloss:2.01854
# [55]	validation_0-mlogloss:2.01613
# [56]	validation_0-mlogloss:2.01360
# [57]	validation_0-mlogloss:2.01113
# [58]	validation_0-mlogloss:2.00877
# [59]	validation_0-mlogloss:2.00655
# [60]	validation_0-mlogloss:2.00425
# [61]	validation_0-mlogloss:2.00184
# [62]	validation_0-mlogloss:1.99978
# [63]	validation_0-mlogloss:1.99763
# [64]	validation_0-mlogloss:1.99530
# [65]	validation_0-mlogloss:1.99297
# [66]	validation_0-mlogloss:1.99072
# [67]	validation_0-mlogloss:1.98855
# [68]	validation_0-mlogloss:1.98629
# [69]	validation_0-mlogloss:1.98417
# [70]	validation_0-mlogloss:1.98217
# [71]	validation_0-mlogloss:1.97991
# [72]	validation_0-mlogloss:1.97786
# [73]	validation_0-mlogloss:1.97588
# [74]	validation_0-mlogloss:1.97377
# [75]	validation_0-mlogloss:1.97164
# [76]	validation_0-mlogloss:1.96946
# [77]	validation_0-mlogloss:1.96743
# [78]	validation_0-mlogloss:1.96538
# [79]	validation_0-mlogloss:1.96338
# [80]	validation_0-mlogloss:1.96137
# [81]	validation_0-mlogloss:1.95951
# [82]	validation_0-mlogloss:1.95760
# [83]	validation_0-mlogloss:1.95558
# [84]	validation_0-mlogloss:1.95337
# [85]	validation_0-mlogloss:1.95139
# [86]	validation_0-mlogloss:1.94940
# [87]	validation_0-mlogloss:1.94755
# [88]	validation_0-mlogloss:1.94567
# [89]	validation_0-mlogloss:1.94389
# [90]	validation_0-mlogloss:1.94202
# [91]	validation_0-mlogloss:1.94024
# [92]	validation_0-mlogloss:1.93842
# [93]	validation_0-mlogloss:1.93635
# [94]	validation_0-mlogloss:1.93464
# [95]	validation_0-mlogloss:1.93287
# [96]	validation_0-mlogloss:1.93117
# [97]	validation_0-mlogloss:1.92943
# [98]	validation_0-mlogloss:1.92770
# [99]	validation_0-mlogloss:1.92604
# [100]	validation_0-mlogloss:1.92435
# [101]	validation_0-mlogloss:1.92273
# [102]	validation_0-mlogloss:1.92108
# [103]	validation_0-mlogloss:1.91958
# [104]	validation_0-mlogloss:1.91783
# [105]	validation_0-mlogloss:1.91627
# [106]	validation_0-mlogloss:1.91464
# [107]	validation_0-mlogloss:1.91298
# [108]	validation_0-mlogloss:1.91157
# [109]	validation_0-mlogloss:1.91000
# [110]	validation_0-mlogloss:1.90839
# [111]	validation_0-mlogloss:1.90674
# [112]	validation_0-mlogloss:1.90536
# [113]	validation_0-mlogloss:1.90398
# [114]	validation_0-mlogloss:1.90244
# [115]	validation_0-mlogloss:1.90095
# [116]	validation_0-mlogloss:1.89953
# [117]	validation_0-mlogloss:1.89810
# [118]	validation_0-mlogloss:1.89654
# [119]	validation_0-mlogloss:1.89516
# [120]	validation_0-mlogloss:1.89368
# [121]	validation_0-mlogloss:1.89218
# [122]	validation_0-mlogloss:1.89055
# [123]	validation_0-mlogloss:1.88916
# [124]	validation_0-mlogloss:1.88781
# [125]	validation_0-mlogloss:1.88653
# [126]	validation_0-mlogloss:1.88520
# [127]	validation_0-mlogloss:1.88386
# [128]	validation_0-mlogloss:1.88228
# [129]	validation_0-mlogloss:1.88095
# [130]	validation_0-mlogloss:1.87964
# [131]	validation_0-mlogloss:1.87820
# [132]	validation_0-mlogloss:1.87685
# [133]	validation_0-mlogloss:1.87544
# [134]	validation_0-mlogloss:1.87403
# [135]	validation_0-mlogloss:1.87268
# [136]	validation_0-mlogloss:1.87146
# [137]	validation_0-mlogloss:1.87010
# [138]	validation_0-mlogloss:1.86893
# [139]	validation_0-mlogloss:1.86774
# [140]	validation_0-mlogloss:1.86646
# [141]	validation_0-mlogloss:1.86536
# [142]	validation_0-mlogloss:1.86422
# [143]	validation_0-mlogloss:1.86313
# [144]	validation_0-mlogloss:1.86178
# [145]	validation_0-mlogloss:1.86062
# [146]	validation_0-mlogloss:1.85932
# [147]	validation_0-mlogloss:1.85818
# [148]	validation_0-mlogloss:1.85705
# [149]	validation_0-mlogloss:1.85589
# [150]	validation_0-mlogloss:1.85480
# [151]	validation_0-mlogloss:1.85346
# [152]	validation_0-mlogloss:1.85235
# [153]	validation_0-mlogloss:1.85122
# [154]	validation_0-mlogloss:1.85011
# [155]	validation_0-mlogloss:1.84917
# [156]	validation_0-mlogloss:1.84791
# [157]	validation_0-mlogloss:1.84679
# [158]	validation_0-mlogloss:1.84576
# [159]	validation_0-mlogloss:1.84458
# [160]	validation_0-mlogloss:1.84359
# [161]	validation_0-mlogloss:1.84256
# [162]	validation_0-mlogloss:1.84147
# [163]	validation_0-mlogloss:1.84019
# [164]	validation_0-mlogloss:1.83930
# [165]	validation_0-mlogloss:1.83824
# [166]	validation_0-mlogloss:1.83729
# [167]	validation_0-mlogloss:1.83627
# [168]	validation_0-mlogloss:1.83522
# [169]	validation_0-mlogloss:1.83425
# [170]	validation_0-mlogloss:1.83329
# [171]	validation_0-mlogloss:1.83238
# [172]	validation_0-mlogloss:1.83149
# [173]	validation_0-mlogloss:1.83043
# [174]	validation_0-mlogloss:1.82942
# [175]	validation_0-mlogloss:1.82859
# [176]	validation_0-mlogloss:1.82771
# [177]	validation_0-mlogloss:1.82684
# [178]	validation_0-mlogloss:1.82585
# [179]	validation_0-mlogloss:1.82502
# [180]	validation_0-mlogloss:1.82411
# [181]	validation_0-mlogloss:1.82305
# [182]	validation_0-mlogloss:1.82205
# [183]	validation_0-mlogloss:1.82117
# [184]	validation_0-mlogloss:1.82036
# [185]	validation_0-mlogloss:1.81948
# [186]	validation_0-mlogloss:1.81853
# [187]	validation_0-mlogloss:1.81757
# [188]	validation_0-mlogloss:1.81664
# [189]	validation_0-mlogloss:1.81577
# [190]	validation_0-mlogloss:1.81499
# [191]	validation_0-mlogloss:1.81411
# [192]	validation_0-mlogloss:1.81331
# [193]	validation_0-mlogloss:1.81252
# [194]	validation_0-mlogloss:1.81172
# [195]	validation_0-mlogloss:1.81087
# [196]	validation_0-mlogloss:1.81004
# [197]	validation_0-mlogloss:1.80912
# [198]	validation_0-mlogloss:1.80849
# [199]	validation_0-mlogloss:1.80765
# [0]	validation_0-mlogloss:2.19265
# [1]	validation_0-mlogloss:2.18817
# [2]	validation_0-mlogloss:2.18362
# [3]	validation_0-mlogloss:2.17926
# [4]	validation_0-mlogloss:2.17498
# [5]	validation_0-mlogloss:2.17082
# [6]	validation_0-mlogloss:2.16677
# [7]	validation_0-mlogloss:2.16257
# [8]	validation_0-mlogloss:2.15819
# [9]	validation_0-mlogloss:2.15419
# [10]	validation_0-mlogloss:2.15003
# [11]	validation_0-mlogloss:2.14608
# [12]	validation_0-mlogloss:2.14195
# [13]	validation_0-mlogloss:2.13826
# [14]	validation_0-mlogloss:2.13436
# [15]	validation_0-mlogloss:2.13074
# [16]	validation_0-mlogloss:2.12671
# [17]	validation_0-mlogloss:2.12300
# [18]	validation_0-mlogloss:2.11941
# [19]	validation_0-mlogloss:2.11593
# [20]	validation_0-mlogloss:2.11254
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [21]	validation_0-mlogloss:2.10898
# [22]	validation_0-mlogloss:2.10558
# [23]	validation_0-mlogloss:2.10232
# [24]	validation_0-mlogloss:2.09899
# [25]	validation_0-mlogloss:2.09570
# [26]	validation_0-mlogloss:2.09242
# [27]	validation_0-mlogloss:2.08937
# [28]	validation_0-mlogloss:2.08600
# [29]	validation_0-mlogloss:2.08289
# [30]	validation_0-mlogloss:2.07964
# [31]	validation_0-mlogloss:2.07628
# [32]	validation_0-mlogloss:2.07316
# [33]	validation_0-mlogloss:2.06986
# [34]	validation_0-mlogloss:2.06691
# [35]	validation_0-mlogloss:2.06393
# [36]	validation_0-mlogloss:2.06112
# [37]	validation_0-mlogloss:2.05802
# [38]	validation_0-mlogloss:2.05506
# [39]	validation_0-mlogloss:2.05208
# [40]	validation_0-mlogloss:2.04909
# [41]	validation_0-mlogloss:2.04606
# [42]	validation_0-mlogloss:2.04319
# [43]	validation_0-mlogloss:2.04040
# [44]	validation_0-mlogloss:2.03764
# [45]	validation_0-mlogloss:2.03503
# [46]	validation_0-mlogloss:2.03229
# [47]	validation_0-mlogloss:2.02951
# [48]	validation_0-mlogloss:2.02691
# [49]	validation_0-mlogloss:2.02422
# [50]	validation_0-mlogloss:2.02160
# [51]	validation_0-mlogloss:2.01878
# [52]	validation_0-mlogloss:2.01631
# [53]	validation_0-mlogloss:2.01373
# [54]	validation_0-mlogloss:2.01113
# [55]	validation_0-mlogloss:2.00849
# [56]	validation_0-mlogloss:2.00594
# [57]	validation_0-mlogloss:2.00343
# [58]	validation_0-mlogloss:2.00109
# [59]	validation_0-mlogloss:1.99872
# [60]	validation_0-mlogloss:1.99644
# [61]	validation_0-mlogloss:1.99406
# [62]	validation_0-mlogloss:1.99209
# [63]	validation_0-mlogloss:1.98980
# [64]	validation_0-mlogloss:1.98739
# [65]	validation_0-mlogloss:1.98515
# [66]	validation_0-mlogloss:1.98280
# [67]	validation_0-mlogloss:1.98037
# [68]	validation_0-mlogloss:1.97816
# [69]	validation_0-mlogloss:1.97589
# [70]	validation_0-mlogloss:1.97375
# [71]	validation_0-mlogloss:1.97145
# [72]	validation_0-mlogloss:1.96919
# [73]	validation_0-mlogloss:1.96732
# [74]	validation_0-mlogloss:1.96525
# [75]	validation_0-mlogloss:1.96300
# [76]	validation_0-mlogloss:1.96069
# ...
# [90]	validation_0-mlogloss:1.57966
# [91]	validation_0-mlogloss:1.57896
# [92]	validation_0-mlogloss:1.57830
# [93]	validation_0-mlogloss:1.57760
# [94]	validation_0-mlogloss:1.57792
# [95]	validation_0-mlogloss:1.57693
# [96]	validation_0-mlogloss:1.57581
# [97]	validation_0-mlogloss:1.57460
# [98]	validation_0-mlogloss:1.57370
# [99]	validation_0-mlogloss:1.57276
# [100]	validation_0-mlogloss:1.57138
# [101]	validation_0-mlogloss:1.57026
# [102]	validation_0-mlogloss:1.57003
# [103]	validation_0-mlogloss:1.56901
# [104]	validation_0-mlogloss:1.56846
# [105]	validation_0-mlogloss:1.56709
# [106]	validation_0-mlogloss:1.56638
# [107]	validation_0-mlogloss:1.56512
# [108]	validation_0-mlogloss:1.56511
# [109]	validation_0-mlogloss:1.56424
# [110]	validation_0-mlogloss:1.56379
# [111]	validation_0-mlogloss:1.56321
# [112]	validation_0-mlogloss:1.56281
# [113]	validation_0-mlogloss:1.56246
# [114]	validation_0-mlogloss:1.56212
# [115]	validation_0-mlogloss:1.56131
# [116]	validation_0-mlogloss:1.56137
# [117]	validation_0-mlogloss:1.56064
# [118]	validation_0-mlogloss:1.56047
# [119]	validation_0-mlogloss:1.55952
# [120]	validation_0-mlogloss:1.55907
# [121]	validation_0-mlogloss:1.55766
# [122]	validation_0-mlogloss:1.55725
# [123]	validation_0-mlogloss:1.55729
# [124]	validation_0-mlogloss:1.55604
# [125]	validation_0-mlogloss:1.55468
# [126]	validation_0-mlogloss:1.55316
# [127]	validation_0-mlogloss:1.55211
# [128]	validation_0-mlogloss:1.55167
# [129]	validation_0-mlogloss:1.55070
# [130]	validation_0-mlogloss:1.55007
# [131]	validation_0-mlogloss:1.54866
# [132]	validation_0-mlogloss:1.54753
# [133]	validation_0-mlogloss:1.54654
# [134]	validation_0-mlogloss:1.54596
# [135]	validation_0-mlogloss:1.54574
# [136]	validation_0-mlogloss:1.54555
# [137]	validation_0-mlogloss:1.54589
# [138]	validation_0-mlogloss:1.54487
# [139]	validation_0-mlogloss:1.54491
# [140]	validation_0-mlogloss:1.54431
# [141]	validation_0-mlogloss:1.54419
# [142]	validation_0-mlogloss:1.54382
# [143]	validation_0-mlogloss:1.54372
# [144]	validation_0-mlogloss:1.54284
# [145]	validation_0-mlogloss:1.54159
# [146]	validation_0-mlogloss:1.54104
# [147]	validation_0-mlogloss:1.54053
# [148]	validation_0-mlogloss:1.53999
# [149]	validation_0-mlogloss:1.53983
# [150]	validation_0-mlogloss:1.53989
# [151]	validation_0-mlogloss:1.53920
# [152]	validation_0-mlogloss:1.53855
# [153]	validation_0-mlogloss:1.53775
# [154]	validation_0-mlogloss:1.53720
# [155]	validation_0-mlogloss:1.53673
# [156]	validation_0-mlogloss:1.53562
# [157]	validation_0-mlogloss:1.53518
# [158]	validation_0-mlogloss:1.53491
# [159]	validation_0-mlogloss:1.53420
# [160]	validation_0-mlogloss:1.53422
# [161]	validation_0-mlogloss:1.53401
# [162]	validation_0-mlogloss:1.53365
# [163]	validation_0-mlogloss:1.53359
# [164]	validation_0-mlogloss:1.53344
# [165]	validation_0-mlogloss:1.53305
# [166]	validation_0-mlogloss:1.53323
# [167]	validation_0-mlogloss:1.53278
# [168]	validation_0-mlogloss:1.53296
# [169]	validation_0-mlogloss:1.53239
# [170]	validation_0-mlogloss:1.53133
# [171]	validation_0-mlogloss:1.53067
# [172]	validation_0-mlogloss:1.53067
# [173]	validation_0-mlogloss:1.53003
# [174]	validation_0-mlogloss:1.52998
# [175]	validation_0-mlogloss:1.52987
# [176]	validation_0-mlogloss:1.52970
# [177]	validation_0-mlogloss:1.52911
# [178]	validation_0-mlogloss:1.52922
# [179]	validation_0-mlogloss:1.52976
# [180]	validation_0-mlogloss:1.53003
# [181]	validation_0-mlogloss:1.52941
# [182]	validation_0-mlogloss:1.52926
# [183]	validation_0-mlogloss:1.52864
# [184]	validation_0-mlogloss:1.52903
# [185]	validation_0-mlogloss:1.52877
# [186]	validation_0-mlogloss:1.52838
# [187]	validation_0-mlogloss:1.52813
# [188]	validation_0-mlogloss:1.52765
# [189]	validation_0-mlogloss:1.52689
# [190]	validation_0-mlogloss:1.52705
# [191]	validation_0-mlogloss:1.52669
# [192]	validation_0-mlogloss:1.52641
# [193]	validation_0-mlogloss:1.52648
# [194]	validation_0-mlogloss:1.52642
# [195]	validation_0-mlogloss:1.52644
# [196]	validation_0-mlogloss:1.52666
# [197]	validation_0-mlogloss:1.52568
# [198]	validation_0-mlogloss:1.52593
# [199]	validation_0-mlogloss:1.52591
# [0]	validation_0-mlogloss:2.14170
# [1]	validation_0-mlogloss:2.09671
# [2]	validation_0-mlogloss:2.05425
# [3]	validation_0-mlogloss:2.01686
# [4]	validation_0-mlogloss:1.98349
# [5]	validation_0-mlogloss:1.95231
# [6]	validation_0-mlogloss:1.92590
# [7]	validation_0-mlogloss:1.89840
# [8]	validation_0-mlogloss:1.87507
# [9]	validation_0-mlogloss:1.85340
# [10]	validation_0-mlogloss:1.83338
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [11]	validation_0-mlogloss:1.81593
# [12]	validation_0-mlogloss:1.79865
# [13]	validation_0-mlogloss:1.78322
# [14]	validation_0-mlogloss:1.76888
# [15]	validation_0-mlogloss:1.75568
# [16]	validation_0-mlogloss:1.74254
# [17]	validation_0-mlogloss:1.73055
# [18]	validation_0-mlogloss:1.72022
# [19]	validation_0-mlogloss:1.70953
# [20]	validation_0-mlogloss:1.69950
# [21]	validation_0-mlogloss:1.69101
# [22]	validation_0-mlogloss:1.68243
# [23]	validation_0-mlogloss:1.67433
# [24]	validation_0-mlogloss:1.66611
# [25]	validation_0-mlogloss:1.65736
# [26]	validation_0-mlogloss:1.65027
# [27]	validation_0-mlogloss:1.64320
# [28]	validation_0-mlogloss:1.63709
# [29]	validation_0-mlogloss:1.63226
# [30]	validation_0-mlogloss:1.62613
# [31]	validation_0-mlogloss:1.62093
# [32]	validation_0-mlogloss:1.61652
# [33]	validation_0-mlogloss:1.61179
# [34]	validation_0-mlogloss:1.60729
# [35]	validation_0-mlogloss:1.60255
# [36]	validation_0-mlogloss:1.59844
# [37]	validation_0-mlogloss:1.59444
# [38]	validation_0-mlogloss:1.59064
# [39]	validation_0-mlogloss:1.58771
# [40]	validation_0-mlogloss:1.58413
# [41]	validation_0-mlogloss:1.57973
# [42]	validation_0-mlogloss:1.57603
# [43]	validation_0-mlogloss:1.57201
# [44]	validation_0-mlogloss:1.56873
# [45]	validation_0-mlogloss:1.56546
# [46]	validation_0-mlogloss:1.56271
# [47]	validation_0-mlogloss:1.56007
# [48]	validation_0-mlogloss:1.55798
# [49]	validation_0-mlogloss:1.55519
# [50]	validation_0-mlogloss:1.55239
# [51]	validation_0-mlogloss:1.54943
# [52]	validation_0-mlogloss:1.54720
# [53]	validation_0-mlogloss:1.54503
# [54]	validation_0-mlogloss:1.54306
# [55]	validation_0-mlogloss:1.54084
# [56]	validation_0-mlogloss:1.53871
# [57]	validation_0-mlogloss:1.53699
# [58]	validation_0-mlogloss:1.53480
# [59]	validation_0-mlogloss:1.53250
# [60]	validation_0-mlogloss:1.53101
# [61]	validation_0-mlogloss:1.52893
# [62]	validation_0-mlogloss:1.52777
# [63]	validation_0-mlogloss:1.52600
# [64]	validation_0-mlogloss:1.52472
# [65]	validation_0-mlogloss:1.52293
# [66]	validation_0-mlogloss:1.52061
# [67]	validation_0-mlogloss:1.51912
# [68]	validation_0-mlogloss:1.51779
# [69]	validation_0-mlogloss:1.51614
# [70]	validation_0-mlogloss:1.51450
# [71]	validation_0-mlogloss:1.51348
# [72]	validation_0-mlogloss:1.51162
# [73]	validation_0-mlogloss:1.50993
# [74]	validation_0-mlogloss:1.50787
# [75]	validation_0-mlogloss:1.50682
# [76]	validation_0-mlogloss:1.50573
# [77]	validation_0-mlogloss:1.50431
# [78]	validation_0-mlogloss:1.50330
# [79]	validation_0-mlogloss:1.50155
# [80]	validation_0-mlogloss:1.50025
# [81]	validation_0-mlogloss:1.49947
# [82]	validation_0-mlogloss:1.49795
# [83]	validation_0-mlogloss:1.49631
# [84]	validation_0-mlogloss:1.49515
# [85]	validation_0-mlogloss:1.49457
# [86]	validation_0-mlogloss:1.49263
# [87]	validation_0-mlogloss:1.49169
# [88]	validation_0-mlogloss:1.49021
# [89]	validation_0-mlogloss:1.48953
# [90]	validation_0-mlogloss:1.48861
# [91]	validation_0-mlogloss:1.48762
# [92]	validation_0-mlogloss:1.48644
# [93]	validation_0-mlogloss:1.48469
# [94]	validation_0-mlogloss:1.48333
# [95]	validation_0-mlogloss:1.48129
# [96]	validation_0-mlogloss:1.48017
# [97]	validation_0-mlogloss:1.47880
# [98]	validation_0-mlogloss:1.47757
# [99]	validation_0-mlogloss:1.47645
# [100]	validation_0-mlogloss:1.47568
# [101]	validation_0-mlogloss:1.47460
# [102]	validation_0-mlogloss:1.47356
# [103]	validation_0-mlogloss:1.47262
# [104]	validation_0-mlogloss:1.47157
# [105]	validation_0-mlogloss:1.47044
# [106]	validation_0-mlogloss:1.46928
# [107]	validation_0-mlogloss:1.46820
# [108]	validation_0-mlogloss:1.46614
# [109]	validation_0-mlogloss:1.46438
# [110]	validation_0-mlogloss:1.46347
# [111]	validation_0-mlogloss:1.46239
# [112]	validation_0-mlogloss:1.46056
# [113]	validation_0-mlogloss:1.45917
# [114]	validation_0-mlogloss:1.45836
# [115]	validation_0-mlogloss:1.45737
# [116]	validation_0-mlogloss:1.45642
# [117]	validation_0-mlogloss:1.45521
# [118]	validation_0-mlogloss:1.45350
# [119]	validation_0-mlogloss:1.45211
# [120]	validation_0-mlogloss:1.45076
# [121]	validation_0-mlogloss:1.44992
# [122]	validation_0-mlogloss:1.44832
# [123]	validation_0-mlogloss:1.44676
# [124]	validation_0-mlogloss:1.44555
# [125]	validation_0-mlogloss:1.44453
# [126]	validation_0-mlogloss:1.44374
# [127]	validation_0-mlogloss:1.44268
# [128]	validation_0-mlogloss:1.44151
# [129]	validation_0-mlogloss:1.44061
# [130]	validation_0-mlogloss:1.43871
# [131]	validation_0-mlogloss:1.43711
# [132]	validation_0-mlogloss:1.43630
# [133]	validation_0-mlogloss:1.43548
# [134]	validation_0-mlogloss:1.43509
# [135]	validation_0-mlogloss:1.43429
# [136]	validation_0-mlogloss:1.43297
# [137]	validation_0-mlogloss:1.43179
# [138]	validation_0-mlogloss:1.43154
# [139]	validation_0-mlogloss:1.43000
# [140]	validation_0-mlogloss:1.42856
# [141]	validation_0-mlogloss:1.42740
# [142]	validation_0-mlogloss:1.42602
# [143]	validation_0-mlogloss:1.42495
# [144]	validation_0-mlogloss:1.42307
# [145]	validation_0-mlogloss:1.42183
# [146]	validation_0-mlogloss:1.42162
# [147]	validation_0-mlogloss:1.42032
# [148]	validation_0-mlogloss:1.41947
# [149]	validation_0-mlogloss:1.41852
# [150]	validation_0-mlogloss:1.41799
# [151]	validation_0-mlogloss:1.41712
# [152]	validation_0-mlogloss:1.41610
# [153]	validation_0-mlogloss:1.41455
# [154]	validation_0-mlogloss:1.41377
# [155]	validation_0-mlogloss:1.41251
# [156]	validation_0-mlogloss:1.41176
# [157]	validation_0-mlogloss:1.41122
# [158]	validation_0-mlogloss:1.41052
# [159]	validation_0-mlogloss:1.40947
# [160]	validation_0-mlogloss:1.40823
# [161]	validation_0-mlogloss:1.40712
# [162]	validation_0-mlogloss:1.40639
# [163]	validation_0-mlogloss:1.40553
# [164]	validation_0-mlogloss:1.40425
# [165]	validation_0-mlogloss:1.40291
# [166]	validation_0-mlogloss:1.40154
# [167]	validation_0-mlogloss:1.40112
# [168]	validation_0-mlogloss:1.40108
# [169]	validation_0-mlogloss:1.40024
# [170]	validation_0-mlogloss:1.39915
# [171]	validation_0-mlogloss:1.39824
# [172]	validation_0-mlogloss:1.39728
# [173]	validation_0-mlogloss:1.39669
# [174]	validation_0-mlogloss:1.39559
# [175]	validation_0-mlogloss:1.39432
# [176]	validation_0-mlogloss:1.39335
# [177]	validation_0-mlogloss:1.39229
# [178]	validation_0-mlogloss:1.39157
# [179]	validation_0-mlogloss:1.39111
# [180]	validation_0-mlogloss:1.39034
# [181]	validation_0-mlogloss:1.38939
# [182]	validation_0-mlogloss:1.38844
# [183]	validation_0-mlogloss:1.38748
# [184]	validation_0-mlogloss:1.38670
# [185]	validation_0-mlogloss:1.38524
# [186]	validation_0-mlogloss:1.38402
# [187]	validation_0-mlogloss:1.38297
# [188]	validation_0-mlogloss:1.38251
# [189]	validation_0-mlogloss:1.38193
# [190]	validation_0-mlogloss:1.38091
# [191]	validation_0-mlogloss:1.38019
# [192]	validation_0-mlogloss:1.37962
# [193]	validation_0-mlogloss:1.37894
# [194]	validation_0-mlogloss:1.37881
# [195]	validation_0-mlogloss:1.37777
# [196]	validation_0-mlogloss:1.37691
# [197]	validation_0-mlogloss:1.37637
# [198]	validation_0-mlogloss:1.37589
# [199]	validation_0-mlogloss:1.37544
# Best parameters found:  {'booster': 'gbtree', 'colsample_bytree': 0.7, 'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 200, 'subsample': 0.8}
# Training set performance:
# Accuracy:  0.87375
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91       908
#            1       0.91      0.94      0.92       860
#            2       0.89      0.92      0.91       884
#            3       0.86      0.94      0.90       892
#            4       0.87      0.87      0.87       863
#            5       0.00      0.00      0.00        67
#            6       1.00      0.05      0.10       172
#            7       0.86      0.88      0.87       881
#            8       0.84      0.85      0.85       873
#
#     accuracy                           0.87      6400
#    macro avg       0.79      0.71      0.70      6400
# weighted avg       0.87      0.87      0.86      6400
#
# Confusion Matrix:
#  [[851   4   8   1  17   0   0  10  17]
#  [  3 805   6  18   7   0   0  14   7]
#  [ 10  20 817   3  17   0   0   7  10]
#  [  4   9   4 841   9   0   0  12  13]
#  [ 31   9  15  23 752   0   0  13  20]
#  [  4  10  10   7   7   0   0  16  13]
#  [ 25   7  24  29  14   0   9  30  34]
#  [ 13  13  12  22  21   0   0 778  22]
#  [ 16  11  22  39  24   0   0  22 739]]
# Test set performance:
# Accuracy:  0.5534041224234854
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.58      0.68      0.63       193
#            1       0.66      0.65      0.65       241
#            2       0.57      0.61      0.59       217
#            3       0.61      0.78      0.68       209
#            4       0.53      0.49      0.51       238
#            5       0.00      0.00      0.00        13
#            6       1.00      0.02      0.05        42
#            7       0.52      0.54      0.53       220
#            8       0.36      0.29      0.32       228
#
#     accuracy                           0.55      1601
#    macro avg       0.54      0.45      0.44      1601
# weighted avg       0.55      0.55      0.54      1601
#
# Confusion Matrix:
#  [[132   4  10   1  16   0   0  13  17]
#  [ 10 156  23  23  10   0   0  12   7]
#  [ 16  24 132   6  15   0   0  12  12]
#  [  2   6   4 162   6   0   0  19  10]
#  [ 34   6  12  15 117   0   0  20  34]
#  [  0   4   2   1   1   0   0   4   1]
#  [  7   3   2   5   4   0   1   6  14]
#  [  8   9  16  19  24   0   0 119  25]
#  [ 19  25  30  35  26   0   0  26  67]]
# An error occurred: 'validation_1'
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Define the parameter grid for XGBoost
param_grid = {
    'max_depth': [3, 5, 7, 10],
    'learning_rate': [0.01, 0.05, 0.1],
    'n_estimators': [100, 200, 300],
    'booster': ['gbtree', 'gblinear'],
    'colsample_bytree': [0.3, 0.7],
    'subsample': [0.5, 0.8]
}

# Initialize the classifier
xgb_classifier = xgb.XGBClassifier(objective='multi:softprob', num_class=len(emotion_dict), n_jobs=10, random_state=42, max_depth=7, learning_rate=0.05, n_estimators=200, colsample_bytree=0.7, subsample=0.8)

# Initialize GridSearchCV
grid_search = GridSearchCV(estimator=xgb_classifier, param_grid=param_grid, cv=3, scoring='accuracy', verbose=1)

# Fit the model
grid_search.fit(combined_x_train, y_train)

# Get the best parameters
best_params = grid_search.best_params_
print("Best parameters found: ", best_params)

# Train the model with the best parameters
best_model = grid_search.best_estimator_

# Evaluate on the training set
train_predictions = best_model.predict(combined_x_train)
train_accuracy = accuracy_score(y_train, train_predictions)
train_classification_report = classification_report(y_train, train_predictions)
train_confusion_matrix = confusion_matrix(y_train, train_predictions)

print("Training set performance:")
print("Accuracy: ", train_accuracy)
print("Classification Report:\n", train_classification_report)
print("Confusion Matrix:\n", train_confusion_matrix)

# Evaluate on the test set
test_predictions = best_model.predict(combined_x_test)
test_accuracy = accuracy_score(y_test, test_predictions)
test_classification_report = classification_report(y_test, test_predictions)
test_confusion_matrix = confusion_matrix(y_test, test_predictions)

print("Test set performance:")
print("Accuracy: ", test_accuracy)
print("Classification Report:\n", test_classification_report)
print("Confusion Matrix:\n", test_confusion_matrix)
# Out:
# Fitting 3 folds for each of 288 candidates, totalling 864 fits
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:04] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:05] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:05] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:06] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:07] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:08] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:09] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:10] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:12] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:21] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:23] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:25] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:27] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:30] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:31] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:32] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:33] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:33] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:34] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:39] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:40] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:42] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:43] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:52] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:54] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:57] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:57] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:58] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:49:59] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:00] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:00] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:01] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:04] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:05] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:07] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:08] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:10] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:12] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:21] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:23] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:24] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:24] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:25] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:26] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:27] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:27] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:30] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:32] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:33] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:35] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:39] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:41] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:43] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:52] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:52] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:53] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:54] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:55] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:57] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:50:58] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:00] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:01] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:05] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:07] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:09] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:11] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:22] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:23] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:24] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:26] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:27] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:31] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:33] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:40] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:42] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:43] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:53] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:54] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:55] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:51:58] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:52:00] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:52:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:52:04] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:52:07] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:52:09] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:52:09] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:52:10] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:52:11] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:52:12] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:52:12] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:52:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:52:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:52:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:52:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:52:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:52:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:52:22] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:52:24] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:52:26] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:52:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:52:31] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:52:33] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:52:35] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:52:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:52:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:52:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:52:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:52:39] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:52:40] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:52:41] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:52:43] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:52:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:52:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:52:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:52:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:52:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# ...
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:58:32] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:58:33] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:58:35] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:58:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:58:39] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:58:42] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:58:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:58:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:58:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:58:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:58:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:58:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:58:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:58:52] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:58:52] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:58:54] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:58:55] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:58:57] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:58:58] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:59:00] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:59:01] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:59:04] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:59:06] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:59:08] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:59:10] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:59:12] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:59:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:59:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:59:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:59:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:59:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:59:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:59:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:59:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:59:22] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:59:23] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:59:25] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:59:26] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:59:27] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:59:30] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:59:32] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:59:34] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:59:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sensenc/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [02:59:39] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "colsample_bytree", "max_depth", "subsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Best parameters found:  {'booster': 'gbtree', 'colsample_bytree': 0.7, 'learning_rate': 0.05, 'max_depth': 10, 'n_estimators': 300, 'subsample': 0.5}
# Training set performance:
# Accuracy:  1.0
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       908
#            1       1.00      1.00      1.00       860
#            2       1.00      1.00      1.00       884
#            3       1.00      1.00      1.00       892
#            4       1.00      1.00      1.00       863
#            5       1.00      1.00      1.00        67
#            6       1.00      1.00      1.00       172
#            7       1.00      1.00      1.00       881
#            8       1.00      1.00      1.00       873
#
#     accuracy                           1.00      6400
#    macro avg       1.00      1.00      1.00      6400
# weighted avg       1.00      1.00      1.00      6400
#
# Confusion Matrix:
#  [[908   0   0   0   0   0   0   0   0]
#  [  0 860   0   0   0   0   0   0   0]
#  [  0   0 884   0   0   0   0   0   0]
#  [  0   0   0 892   0   0   0   0   0]
#  [  0   0   0   0 863   0   0   0   0]
#  [  0   0   0   0   0  67   0   0   0]
#  [  0   0   0   0   0   0 172   0   0]
#  [  0   0   0   0   0   0   0 881   0]
#  [  0   0   0   0   0   0   0   0 873]]
# Test set performance:
# Accuracy:  0.6258588382261087
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.65      0.70      0.67       193
#            1       0.72      0.74      0.73       241
#            2       0.62      0.65      0.63       217
#            3       0.67      0.85      0.75       209
#            4       0.60      0.56      0.58       238
#            5       0.87      1.00      0.93        13
#            6       1.00      0.81      0.89        42
#            7       0.56      0.53      0.55       220
#            8       0.41      0.32      0.36       228
#
#     accuracy                           0.63      1601
#    macro avg       0.68      0.68      0.68      1601
# weighted avg       0.62      0.63      0.62      1601
#
# Confusion Matrix:
#  [[135   4   4   3  26   0   0   4  17]
#  [  5 179  21  17   4   0   0   6   9]
#  [ 14  20 140   9   9   1   0  12  12]
#  [  1   5   3 177   4   1   0  12   6]
#  [ 29   6  10  11 134   0   0  25  23]
#  [  0   0   0   0   0  13   0   0   0]
#  [  0   2   0   0   2   0  34   0   4]
#  [  8   5  17  20  19   0   0 117  34]
#  [ 16  26  31  26  24   0   0  32  73]]

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

def evaluate_model(model, X_train, y_train, X_test, y_test):
    """
    Evaluates the performance of the XGBoost model on the training and test sets.
    
    Args:
    model (xgboost.XGBClassifier): The trained XGBoost model.
    X_train (numpy.ndarray): The training input data.
    y_train (numpy.ndarray): The training target variable.
    X_test (numpy.ndarray): The test input data.
    y_test (numpy.ndarray): The test target variable.
    
    Returns:
    dict: A dictionary containing the performance metrics for the training and test sets.
    """
    # Make predictions on the training and test sets
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)
    
    # Calculate performance metrics
    train_accuracy = accuracy_score(y_train, y_train_pred)
    train_f1 = f1_score(y_train, y_train_pred, average='macro')
    train_precision = precision_score(y_train, y_train_pred, average='macro')
    train_recall = recall_score(y_train, y_train_pred, average='macro')
    
    test_accuracy = accuracy_score(y_test, y_test_pred)
    test_f1 = f1_score(y_test, y_test_pred, average='macro')
    test_precision = precision_score(y_test, y_test_pred, average='macro')
    test_recall = recall_score(y_test, y_test_pred, average='macro')
    
    # Return the performance metrics
    return {
        'train_accuracy': train_accuracy,
        'train_f1': train_f1,
        'train_precision': train_precision,
        'train_recall': train_recall,
        'test_accuracy': test_accuracy,
        'test_f1': test_f1,
        'test_precision': test_precision,
        'test_recall': test_recall
    }

# %%
import xgboost as xgb



feature_importances = best_model.feature_importances_
sorted_indices = np.argsort(feature_importances)[::-1]
top_57_features = sorted_indices[:57]


combined_x_train_top_57 = combined_x_train[:, top_57_features]
combined_x_test_top_57 = combined_x_test[:, top_57_features]

best_model_ = xgb.XGBClassifier(objective='multi:softprob', num_class=len(emotion_dict), n_jobs=10, random_state=42, max_depth=7, learning_rate=0.05, n_estimators=200, colsample_bytree=0.7, subsample=0.8)
# xgb_classifier = xgb.XGBClassifier(objective='multi:softprob', num_class=len(emotion_dict), n_jobs=10, random_state=42, max_depth=7, learning_rate=0.05, n_estimators=200, colsample_bytree=0.7, subsample=0.8)

# Initialize GridSearchCV
# param_grid = {
#     'max_depth': [3, 5, 7, 10],
#     'learning_rate': [0.01, 0.05, 0.1],
#     'n_estimators': [100, 200, 300],
#     'booster': ['gbtree', 'gblinear'],
#     'colsample_bytree': [0.3, 0.7],
#     'subsample': [0.5, 0.8]
# }
# grid_search = GridSearchCV(estimator=best_model, param_grid=param_grid, cv=3, scoring='accuracy', verbose=1)

# Fit the model
# grid_search.fit(combined_x_train, y_train)

# Get the best parameters
best_params = best_model_.best_params_
best_model.fit(combined_x_train_top_57, y_train)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[93], line 5
#       1 import xgboost as xgb
# ----> 5 feature_importances = best_model.feature_importances_
#       6 sorted_indices = np.argsort(feature_importances)[::-1]
#       7 top_57_features = sorted_indices[:57]
#
# File ~/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/sklearn.py:1314, in XGBModel.feature_importances_(self)
#    1299 @property
#    1300 def feature_importances_(self) -> np.ndarray:
#    1301     """Feature importances property, return depends on `importance_type`
#    1302     parameter. When model trained with multi-class/multi-label/multi-target dataset,
#    1303     the feature importance is "averaged" over all targets. The "average" is defined
#    (...)
#    1312
#    1313     """
# -> 1314     b: Booster = self.get_booster()
#    1316     def dft() -> str:
#    1317         return "weight" if self.booster == "gblinear" else "gain"
#
# File ~/anaconda3/envs/sound_detection_project/lib/python3.10/site-packages/xgboost/sklearn.py:725, in XGBModel.get_booster(self)
#     722 if not self.__sklearn_is_fitted__():
#     723     from sklearn.exceptions import NotFittedError
# --> 725     raise NotFittedError("need to call fit or load_model beforehand")
#     726 return self._Booster
#
# NotFittedError: need to call fit or load_model beforehand

# %%
train_predictions = best_model.predict(combined_x_train_top_57)
train_accuracy = accuracy_score(y_train, train_predictions)
train_classification_report = classification_report(y_train, train_predictions)
train_confusion_matrix = confusion_matrix(y_train, train_predictions)

print("Training set performance:")
print("Accuracy: ", train_accuracy)
print("Classification Report:\n", train_classification_report)
print("Confusion Matrix:\n", train_confusion_matrix)

# Evaluate on the test set
test_predictions = best_model.predict(combined_x_test_top_57)
test_accuracy = accuracy_score(y_test, test_predictions)
test_classification_report = classification_report(y_test, test_predictions)
test_confusion_matrix = confusion_matrix(y_test, test_predictions)

print("Test set performance:")
print("Accuracy: ", test_accuracy)
print("Classification Report:\n", test_classification_report)
print("Confusion Matrix:\n", test_confusion_matrix)
# Out:
# Training set performance:
# Accuracy:  0.58796875
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.52      0.75      0.62       908
#            1       0.82      0.49      0.62       860
#            2       0.67      0.61      0.64       884
#            3       0.53      0.85      0.65       892
#            4       0.65      0.48      0.56       863
#            5       0.88      0.54      0.67        67
#            6       0.90      0.54      0.68       172
#            7       0.50      0.53      0.52       881
#            8       0.54      0.41      0.46       873
#
#     accuracy                           0.59      6400
#    macro avg       0.67      0.58      0.60      6400
# weighted avg       0.62      0.59      0.58      6400
#
# Confusion Matrix:
#  [[681  13  36  28  37   1   2  61  49]
#  [ 83 422  43 160  26   0   0  82  44]
#  [143  15 537  29  43   0   0  65  52]
#  [ 15   7   2 755  18   0   2  67  26]
#  [140  19  66  96 418   0   1  70  53]
#  [  9   1   0   3   6  36   0   5   7]
#  [ 22   1   4  22   5   1  93  13  11]
#  [ 78  13  52 161  51   1   2 466  57]
#  [129  21  64 162  39   2   3  98 355]]
# Test set performance:
# Accuracy:  0.39787632729544037
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.38      0.61      0.47       193
#            1       0.56      0.28      0.37       241
#            2       0.41      0.41      0.41       217
#            3       0.44      0.75      0.55       209
#            4       0.42      0.33      0.37       238
#            5       0.40      0.15      0.22        13
#            6       0.69      0.26      0.38        42
#            7       0.30      0.33      0.31       220
#            8       0.28      0.19      0.23       228
#
#     accuracy                           0.40      1601
#    macro avg       0.43      0.37      0.37      1601
# weighted avg       0.41      0.40      0.38      1601
#
# Confusion Matrix:
#  [[118   5  10  10  25   0   0  12  13]
#  [ 24  67  39  53   9   0   0  31  18]
#  [ 49   7  88  14  24   1   0  23  11]
#  [  4   6   4 156   8   0   1  18  12]
#  [ 44   3  22  30  79   0   1  37  22]
#  [  5   1   0   1   0   2   0   3   1]
#  [  4   1   2   6   5   1  11   5   7]
#  [ 23  12  21  44  22   0   1  73  24]
#  [ 36  18  29  40  16   1   2  43  43]]

# %%
performance_metrics = evaluate_model(best_model, combined_x_train_top_57, y_train, combined_x_test_top_57, y_test)
print(performance_metrics)
# Out:
# {'train_accuracy': 0.58796875, 'train_f1': 0.6001226769772502, 'train_precision': 0.6695241035148807, 'train_recall': 0.5769480482414612, 'test_accuracy': 0.39787632729544037, 'test_f1': 0.3686765133166378, 'test_precision': 0.4314576230460861, 'test_recall': 0.3677163401736452}

# %%
# Extract feature names from x_train_audio and x_train_text
audio_feature_names = x_train_audio.columns.difference(['wav_file', 'label']).tolist()
text_feature_names = pd.DataFrame(x_train_text).columns.to_list()


# Combine feature names
combined_feature_names = audio_feature_names + text_feature_names


# Plot feature importances
ax = xgb.plot_importance(xgb_classifier, max_num_features=10, height=0.5, show_values=False)
fig = ax.figure
fig.set_size_inches(8, 8)

# Add feature names to the plot
ax.set_yticklabels([combined_feature_names[i] for i in ax.get_yticks().astype(int)])

# Save the plot
plt.savefig('feature_importance.png')

# Print contribution scores with feature names
contribution_scores = xgb_classifier.feature_importances_
feature_importance_dict = {feature: score for feature, score in zip(combined_feature_names, contribution_scores)}

# Sort the feature importance dictionary by the importance scores
sorted_feature_importance = sorted(feature_importance_dict.items(), key=lambda item: item[1], reverse=True)

# Print sorted feature importances
for feature, importance in sorted_feature_importance:
    print(f"{feature}: {importance}")
# Out:
# wouldn: 0.01662360318005085
# um: 0.014896871522068977
# sig_std: 0.01385783962905407
# laughter: 0.013064436614513397
# excited: 0.012893464416265488
# things: 0.011699915863573551
# just don: 0.011327333748340607
# sig_mean: 0.010556924156844616
# rmse_mean: 0.010266798548400402
# sure: 0.01013786718249321
# turn: 0.010064375586807728
# great: 0.00988799799233675
# okay: 0.009681154042482376
# line: 0.009540049359202385
# point: 0.009471648372709751
# flashlight: 0.009428881108760834
# really: 0.009420731104910374
# live: 0.009364232420921326
# laugh: 0.00924843829125166
# isn: 0.00901144277304411
# yeah: 0.009000161662697792
# need: 0.008992020040750504
# doing: 0.008803359232842922
# job: 0.008690648712217808
# look: 0.008690549992024899
# mfcc_6_mean: 0.008682227693498135
# know like: 0.008618813939392567
# rmse_std: 0.00860392116010189
# oh: 0.00857167225331068
# come: 0.008510272018611431
# day: 0.008458429016172886
# thank: 0.008440283127129078
# good: 0.008298545144498348
# love: 0.008293723687529564
# long: 0.008202948607504368
# know: 0.008054453879594803
# guess: 0.008018244057893753
# thought: 0.007985652424395084
# married: 0.00788667518645525
# mfcc_1_mean: 0.00786014273762703
# uh: 0.00784365739673376
# god: 0.007792372722178698
# business: 0.007735616527497768
# lot: 0.007679504808038473
# feel: 0.007514942437410355
# mfcc_8_mean: 0.007496053818613291
# came: 0.007473383564502001
# won: 0.007428161799907684
# think: 0.0074131363071501255
# know know: 0.007404050789773464
# ve: 0.007373339030891657
# little: 0.007370420265942812
# happy: 0.007356037385761738
# auto_corr_std: 0.007203575223684311
# mfcc_3_mean: 0.007185960654169321
# mfcc_2_mean: 0.007160824257880449
# annie: 0.007157209329307079
# auto_corr_max: 0.0071352021768689156
# does: 0.00712228799238801
# ask: 0.007120609283447266
# cause: 0.007097835652530193
# don know: 0.007088841870427132
# sorry: 0.007087597623467445
# thing: 0.007033307570964098
# did: 0.007025630678981543
# help: 0.007004308979958296
# yes: 0.006929127965122461
# time: 0.006915299221873283
# understand: 0.006905085872858763
# remember: 0.006897946819663048
# let: 0.006869956851005554
# fish: 0.006849761586636305
# maybe: 0.006849628407508135
# mfcc_10_mean: 0.0068403929471969604
# want: 0.006811885163187981
# thinking: 0.006786301266402006
# don: 0.006630705203860998
# mom: 0.0065532466396689415
# ve got: 0.006552368402481079
# got: 0.006526933517307043
# mfcc_12_mean: 0.006515128538012505
# said: 0.006512964144349098
# right: 0.006437722127884626
# mfcc_11_std: 0.006437011994421482
# mfcc_5_mean: 0.00640986068174243
# away: 0.006353198084980249
# going: 0.006344742141664028
# fine: 0.006325854454189539
# went: 0.006298269610852003
# mfcc_9_mean: 0.006270748563110828
# like: 0.0062646279111504555
# man: 0.006218593567609787
# just: 0.006178461946547031
# years: 0.006169191095978022
# kind: 0.006141845602542162
# mfcc_4_mean: 0.006125895772129297
# money: 0.006081344094127417
# mfcc_3_std: 0.006074320059269667
# coming: 0.005975308828055859
# mfcc_2_std: 0.005972592160105705
# wrong: 0.0059705874882638454
# gonna: 0.005947244819253683
# silence: 0.005931982304900885
# mfcc_13_std: 0.0058959596790373325
# new: 0.00589290726929903
# mfcc_10_std: 0.005892796441912651
# mfcc_12_std: 0.0058799004182219505
# tell: 0.005846971645951271
# mfcc_7_mean: 0.005844293627887964
# ll: 0.0058071850799024105
# didn: 0.0057821073569357395
# don want: 0.005747184157371521
# year: 0.005740001797676086
# say: 0.005681425333023071
# mfcc_5_std: 0.005675159860402346
# mfcc_1_std: 0.005647494923323393
# mel_std: 0.0056109013967216015
# mfcc_7_std: 0.005585016217082739
# mean: 0.005577068775892258
# mfcc_13_mean: 0.0055736214853823185
# mfcc_11_mean: 0.005552305839955807
# probably: 0.005541822873055935
# mfcc_8_std: 0.005491162650287151
# make: 0.005476470571011305
# mel_mean: 0.005471209064126015
# mfcc_9_std: 0.005384606309235096
# people: 0.005359828006476164
# way: 0.005349559709429741
# work: 0.005333650391548872
# believe: 0.005327759310603142
# harmonic: 0.005311253946274519
# mfcc_6_std: 0.005301071330904961
# mfcc_4_std: 0.005244228523224592
# life: 0.005162385292351246
# getting: 0.005073350854218006
# waiting: 0.0046525862999260426

# %%
# Get the feature importance scores
importance_scores = xgb_classifier.feature_importances_

# Define a range of threshold values
thresholds = np.sort(xgb_classifier.feature_importances_)

# Initialize lists to store the results
num_features = []
accuracies = []

# Iterate over the threshold values
for threshold in thresholds:
    # Select features using the current threshold
    selector = SelectFromModel(xgb_classifier, threshold=threshold, prefit=True)
    X_train_selected = selector.transform(combined_x_train)
    X_test_selected = selector.transform(combined_x_test)

    # Train a new XGBoost model with the selected features
    selected_model = xgb.XGBClassifier(n_estimators=300, learning_rate=0.05, random_state=42)
    selected_model.fit(X_train_selected, y_train)

    # Evaluate the model on the test set
    y_pred = selected_model.predict(X_test_selected)
    accuracy = accuracy_score(y_test, y_pred)

    # Store the number of selected features and accuracy
    num_features.append(X_train_selected.shape[1])
    accuracies.append(accuracy)

    # Report progress
    print(f'> threshold={threshold}, features={X_train_selected.shape[1]}, accuracy={accuracy}')

# Plot the results
plt.figure(figsize=(8, 6))
plt.plot(num_features, accuracies, marker='o')
plt.xlabel('Number of Selected Features')
plt.ylabel('Accuracy')
plt.title('Accuracy vs. Number of Selected Features')
plt.grid(True)
plt.show()

# Find the optimal threshold
optimal_threshold_index = np.argmax(accuracies)
optimal_threshold = thresholds[optimal_threshold_index]
optimal_num_features = num_features[optimal_threshold_index]

print(f"Optimal Threshold: {optimal_threshold:.4f}")
print(f"Number of Selected Features: {optimal_num_features}")
print(f"Accuracy at Optimal Threshold: {accuracies[optimal_threshold_index]:.4f}")
# Out:
# > threshold=0.0046525862999260426, features=136, accuracy=0.6008744534665834
# > threshold=0.005073350854218006, features=135, accuracy=0.6046221111805122
# > threshold=0.005162385292351246, features=134, accuracy=0.603372891942536
# > threshold=0.005244228523224592, features=133, accuracy=0.5965021861336665
# > threshold=0.005301071330904961, features=132, accuracy=0.5952529668956902
# > threshold=0.005311253946274519, features=131, accuracy=0.5952529668956902
# > threshold=0.005327759310603142, features=130, accuracy=0.5927545284197376
# > threshold=0.005333650391548872, features=129, accuracy=0.5883822610868208
# > threshold=0.005349559709429741, features=128, accuracy=0.5908806995627732
# > threshold=0.005359828006476164, features=127, accuracy=0.5940037476577139
# > threshold=0.005384606309235096, features=126, accuracy=0.5965021861336665
# > threshold=0.005471209064126015, features=125, accuracy=0.5940037476577139
# > threshold=0.005476470571011305, features=124, accuracy=0.5883822610868208
# > threshold=0.005491162650287151, features=123, accuracy=0.5858838226108682
# > threshold=0.005541822873055935, features=122, accuracy=0.5858838226108682
# > threshold=0.005552305839955807, features=121, accuracy=0.589631480324797
# > threshold=0.0055736214853823185, features=120, accuracy=0.5796377264209869
# > threshold=0.005577068775892258, features=119, accuracy=0.5858838226108682
# > threshold=0.005585016217082739, features=118, accuracy=0.5808869456589631
# > threshold=0.0056109013967216015, features=117, accuracy=0.5727670206121174
# > threshold=0.005647494923323393, features=116, accuracy=0.5708931917551531
# > threshold=0.005675159860402346, features=115, accuracy=0.5702685821361649
# > threshold=0.005681425333023071, features=114, accuracy=0.5727670206121174
# > threshold=0.005740001797676086, features=113, accuracy=0.5690193628981887
# > threshold=0.005747184157371521, features=112, accuracy=0.5690193628981887
# > threshold=0.0057821073569357395, features=111, accuracy=0.5677701436602124
# > threshold=0.0058071850799024105, features=110, accuracy=0.5652717051842598
# > threshold=0.005844293627887964, features=109, accuracy=0.5671455340412243
# > threshold=0.005846971645951271, features=108, accuracy=0.565896314803248
# > threshold=0.0058799004182219505, features=107, accuracy=0.5633978763272954
# > threshold=0.005892796441912651, features=106, accuracy=0.561524047470331
# > threshold=0.00589290726929903, features=105, accuracy=0.5565271705184259
# > threshold=0.0058959596790373325, features=104, accuracy=0.5565271705184259
# > threshold=0.005931982304900885, features=103, accuracy=0.5490318550905684
# > threshold=0.005947244819253683, features=102, accuracy=0.5540287320424735
# > threshold=0.0059705874882638454, features=101, accuracy=0.5477826358525921
# > threshold=0.005972592160105705, features=100, accuracy=0.5559025608994379
# > threshold=0.005975308828055859, features=99, accuracy=0.5440349781386633
# > threshold=0.006074320059269667, features=98, accuracy=0.5402873204247346
# > threshold=0.006081344094127417, features=97, accuracy=0.5484072454715803
# > threshold=0.006125895772129297, features=96, accuracy=0.5534041224234854
# > threshold=0.006141845602542162, features=95, accuracy=0.5502810743285447
# > threshold=0.006169191095978022, features=94, accuracy=0.5452841973766396
# > threshold=0.006178461946547031, features=93, accuracy=0.5509056839475328
# > threshold=0.006218593567609787, features=92, accuracy=0.5415365396627108
# > threshold=0.0062646279111504555, features=91, accuracy=0.5465334166146159
# > threshold=0.006270748563110828, features=90, accuracy=0.5490318550905684
# > threshold=0.006298269610852003, features=89, accuracy=0.5271705184259837
# > threshold=0.006325854454189539, features=88, accuracy=0.5309181761399125
# > threshold=0.006344742141664028, features=87, accuracy=0.5252966895690193
# > threshold=0.006353198084980249, features=86, accuracy=0.5334166146158651
# > threshold=0.00640986068174243, features=85, accuracy=0.5271705184259837
# > threshold=0.006437011994421482, features=84, accuracy=0.5309181761399125
# > threshold=0.006437722127884626, features=83, accuracy=0.5146783260462211
# > threshold=0.006512964144349098, features=82, accuracy=0.5146783260462211
# > threshold=0.006515128538012505, features=81, accuracy=0.5034353529044348
# > threshold=0.006526933517307043, features=80, accuracy=0.5003123048094941
# > threshold=0.006552368402481079, features=79, accuracy=0.5040599625234229
# > threshold=0.0065532466396689415, features=78, accuracy=0.5034353529044348
# > threshold=0.006630705203860998, features=77, accuracy=0.5053091817613992
# > threshold=0.006786301266402006, features=76, accuracy=0.5059337913803873
# > threshold=0.006811885163187981, features=75, accuracy=0.4915677701436602
# > threshold=0.0068403929471969604, features=74, accuracy=0.5009369144284822
# > threshold=0.006849628407508135, features=73, accuracy=0.5071830106183636
# > threshold=0.006849761586636305, features=72, accuracy=0.5084322298563397
# > threshold=0.006869956851005554, features=71, accuracy=0.5028107432854466
# > threshold=0.006897946819663048, features=70, accuracy=0.5059337913803873
# > threshold=0.006905085872858763, features=69, accuracy=0.5053091817613992
# > threshold=0.006915299221873283, features=68, accuracy=0.5009369144284822
# > threshold=0.006929127965122461, features=67, accuracy=0.5015615240474703
# > threshold=0.007004308979958296, features=66, accuracy=0.49843847595252966
# > threshold=0.007025630678981543, features=65, accuracy=0.49531542785758903
# > threshold=0.007033307570964098, features=64, accuracy=0.49406620861961276
# > threshold=0.007087597623467445, features=63, accuracy=0.49656464709556525
# > threshold=0.007088841870427132, features=62, accuracy=0.5065584009993754
# > threshold=0.007097835652530193, features=61, accuracy=0.5028107432854466
# > threshold=0.007120609283447266, features=60, accuracy=0.5103060587133041
# > threshold=0.00712228799238801, features=59, accuracy=0.5065584009993754
# > threshold=0.0071352021768689156, features=58, accuracy=0.5071830106183636
# > threshold=0.007157209329307079, features=57, accuracy=0.5109306683322923
# > threshold=0.007160824257880449, features=56, accuracy=0.5065584009993754
# > threshold=0.007185960654169321, features=55, accuracy=0.4871955028107433
# > threshold=0.007203575223684311, features=54, accuracy=0.47657713928794504
# > threshold=0.007356037385761738, features=53, accuracy=0.4665833853841349
# > threshold=0.007370420265942812, features=52, accuracy=0.46408494690818236
# > threshold=0.007373339030891657, features=51, accuracy=0.4590880699562773
# > threshold=0.007404050789773464, features=50, accuracy=0.4572142410993129
# > threshold=0.0074131363071501255, features=49, accuracy=0.452841973766396
# > threshold=0.007428161799907684, features=48, accuracy=0.4565896314803248
# > threshold=0.007473383564502001, features=47, accuracy=0.45346658338538415
# > threshold=0.007496053818613291, features=46, accuracy=0.4522173641474079
# > threshold=0.007514942437410355, features=45, accuracy=0.4166146158650843
# > threshold=0.007679504808038473, features=44, accuracy=0.4178638351030606
# > threshold=0.007735616527497768, features=43, accuracy=0.41911305434103685
# > threshold=0.007792372722178698, features=42, accuracy=0.4184884447220487
# > threshold=0.00784365739673376, features=41, accuracy=0.41536539662710803
# > threshold=0.00786014273762703, features=40, accuracy=0.41536539662710803
# > threshold=0.00788667518645525, features=39, accuracy=0.40974391005621486
# > threshold=0.007985652424395084, features=38, accuracy=0.40537164272329795
# > threshold=0.008018244057893753, features=37, accuracy=0.4041224234853217
# > threshold=0.008054453879594803, features=36, accuracy=0.3966271080574641
# > threshold=0.008202948607504368, features=35, accuracy=0.3966271080574641
# > threshold=0.008293723687529564, features=34, accuracy=0.3891317926296065
# > threshold=0.008298545144498348, features=33, accuracy=0.40162398500936913
# > threshold=0.008440283127129078, features=32, accuracy=0.3891317926296065
# > threshold=0.008458429016172886, features=31, accuracy=0.391630231105559
# > threshold=0.008510272018611431, features=30, accuracy=0.3910056214865709
# > threshold=0.00857167225331068, features=29, accuracy=0.38788257339163024
# > threshold=0.00860392116010189, features=28, accuracy=0.38975640224859465
# > threshold=0.008618813939392567, features=27, accuracy=0.3816364772017489
# > threshold=0.008682227693498135, features=26, accuracy=0.37726420986883197
# > threshold=0.008690549992024899, features=25, accuracy=0.3447845096814491
# > threshold=0.008690648712217808, features=24, accuracy=0.34166146158650845
# > threshold=0.008803359232842922, features=23, accuracy=0.3435352904434728
# > threshold=0.008992020040750504, features=22, accuracy=0.34291068082448467
# > threshold=0.009000161662697792, features=21, accuracy=0.3410368519675203
# > threshold=0.00901144277304411, features=20, accuracy=0.3454091193004372
# > threshold=0.00924843829125166, features=19, accuracy=0.3466583385384135
# > threshold=0.009364232420921326, features=18, accuracy=0.3391630231105559
# > threshold=0.009420731104910374, features=17, accuracy=0.33853841349156777
# > threshold=0.009428881108760834, features=16, accuracy=0.33354153653966273
# > threshold=0.009471648372709751, features=15, accuracy=0.3329169269206746
# > threshold=0.009540049359202385, features=14, accuracy=0.3372891942535915
# > threshold=0.009681154042482376, features=13, accuracy=0.33229231730168646
# > threshold=0.00988799799233675, features=12, accuracy=0.3291692692067458
# > threshold=0.010064375586807728, features=11, accuracy=0.33479075577763895
# > threshold=0.01013786718249321, features=10, accuracy=0.3266708307307932
# > threshold=0.010266798548400402, features=9, accuracy=0.3198001249219238
# > threshold=0.010556924156844616, features=8, accuracy=0.316052467207995
# > threshold=0.011327333748340607, features=7, accuracy=0.2873204247345409
# > threshold=0.011699915863573551, features=6, accuracy=0.28794503435352903
# > threshold=0.012893464416265488, features=5, accuracy=0.2835727670206121
# > threshold=0.013064436614513397, features=4, accuracy=0.2835727670206121
# > threshold=0.01385783962905407, features=3, accuracy=0.2623360399750156
# > threshold=0.014896871522068977, features=2, accuracy=0.1405371642723298
# > threshold=0.01662360318005085, features=1, accuracy=0.1267957526545909
# Optimal Threshold: 0.0051
# Number of Selected Features: 135
# Accuracy at Optimal Threshold: 0.6046

# %%
svc_classifier = LinearSVC()

svc_classifier.fit(combined_x_train, y_train)

# Predict
pred = svc_classifier.predict(combined_x_test)

# Results
one_hot_true = one_hot_encoder(y_test, len(pred), len(emotion_dict))
print('Test Set Accuracy =  {0:.3f}'.format(accuracy_score(y_test, pred)))
print('Test Set F-score =  {0:.3f}'.format(f1_score(y_test, pred, average='macro')))
print('Test Set Precision =  {0:.3f}'.format(precision_score(y_test, pred, average='macro')))
print('Test Set Recall =  {0:.3f}'.format(recall_score(y_test, pred, average='macro')))
plot_confusion_matrix(confusion_matrix(y_test, pred), classes=emo_keys)
(y_test, pred_probs)

with open('pred_probas/combined_svc_classifier_model.pkl', 'wb') as f:
    pickle.dump(svc_classifier, f)
    
with open('trained_models/combined/SVC.pkl', 'wb') as f:
    pickle.dump(svc_classifier, f)
# Out:
# Test Set Accuracy =  0.649
# Test Set F-score =  0.662
# Test Set Precision =  0.664
# Test Set Recall =  0.666
# Confusion matrix, without normalization
# [[125   7  64   7   5  16]
#  [  8 190  36   8  11  47]
#  [ 42  33 392  16  24  76]
#  [  0   0  15 232   0   0]
#  [  1   3  25  14 198   0]
#  [ 20  48 135  14  12 136]]

# %%
mnb_classifier = MultinomialNB()

mnb_classifier.fit(combined_x_train, y_train)

# Predict
pred_probs = mnb_classifier.predict_proba(combined_x_test)

# Results
display_results(y_test, pred_probs)

with open('pred_probas/combined_mnb_classifier.pkl', 'wb') as f:
    pickle.dump(pred_probs, f)
    
with open('trained_models/combined/MNB.pkl', 'wb') as f:
    pickle.dump(mnb_classifier, f)
# Out:
# Test Set Accuracy =  0.607
# Test Set F-score =  0.608
# Test Set Precision =  0.719
# Test Set Recall =  0.574
# Confusion matrix, without normalization
# [[ 88  13 107   3   5   8]
#  [  4 166  94   3   8  25]
#  [ 18  20 509   3   9  24]
#  [  0   0  70 177   0   0]
#  [  0   8  74   0 159   0]
#  [  4  30 224   9   7  91]]

# %%
mlp_classifier = MLPClassifier(hidden_layer_sizes=(500, ), activation='relu', solver='adam', alpha=0.0001,
                               batch_size='auto', learning_rate='adaptive', learning_rate_init=0.01,
                               power_t=0.5, max_iter=1000, shuffle=True, random_state=None, tol=0.0001,
                               verbose=False, warm_start=True, momentum=0.8, nesterovs_momentum=True,
                               early_stopping=False, validation_fraction=0.1, beta_1=0.9, beta_2=0.999,
                               epsilon=1e-08)

mlp_classifier.fit(combined_x_train, y_train)

# Predict
pred_probs = mlp_classifier.predict_proba(combined_x_test)

# Results
display_results(y_test, pred_probs)

with open('pred_probas/combined_mlp_classifier.pkl', 'wb') as f:
    pickle.dump(pred_probs, f)
    
with open('trained_models/combined/MLP.pkl', 'wb') as f:
    pickle.dump(mlp_classifier, f)
# Out:
# Test Set Accuracy =  0.665
# Test Set F-score =  0.681
# Test Set Precision =  0.676
# Test Set Recall =  0.690
# Confusion matrix, without normalization
# [[120  17  63   3   3  18]
#  [ 13 182  35   6  12  52]
#  [ 50  42 381   9  17  84]
#  [  0   0   0 247   0   0]
#  [  1   0  10   3 227   0]
#  [ 22  57 126   5   8 147]]

# %%
lr_classifier = LogisticRegression(solver='lbfgs', multi_class='multinomial', max_iter=1000)

lr_classifier.fit(combined_x_train, y_train)

# Predict
pred_probs = lr_classifier.predict_proba(combined_x_test)

# Results
display_results(y_test, pred_probs)

with open('pred_probas/combined_lr_classifier.pkl', 'wb') as f:
    pickle.dump(pred_probs, f)
    
with open('trained_models/combined/LR.pkl', 'wb') as f:
    pickle.dump(lr_classifier, f)
# Out:
# Test Set Accuracy =  0.631
# Test Set F-score =  0.643
# Test Set Precision =  0.686
# Test Set Recall =  0.620
# Confusion matrix, without normalization
# [[119   8  77   1   5  14]
#  [  9 175  59   4  14  39]
#  [ 28  29 450   4  18  54]
#  [ 10   0  53 184   0   0]
#  [  5   7  49   2 173   5]
#  [  7  34 166   9  13 136]]

# %%
# Out:
# [0.00794865 0.00733964 0.00552868 ... 0.         0.         0.        ]

# %%
# Load predicted probabilities
with open('pred_probas/combined_rf_classifier.pkl', 'rb') as f:
    rf_pred_probs = pickle.load(f)

with open('pred_probas/combined_xgb_classifier.pkl', 'rb') as f:
    xgb_pred_probs = pickle.load(f)
    
with open('pred_probas/combined_svc_classifier_model.pkl', 'rb') as f:
    svc_preds = pickle.load(f)
    
with open('pred_probas/combined_mnb_classifier.pkl', 'rb') as f:
    mnb_pred_probs = pickle.load(f)
    
with open('pred_probas/combined_mlp_classifier.pkl', 'rb') as f:
    mlp_pred_probs = pickle.load(f)
    
with open('pred_probas/combined_lr_classifier.pkl', 'rb') as f:
    lr_pred_probs = pickle.load(f)

with open('pred_probas/combined_lstm_classifier.pkl', 'rb') as f:
    lstm_pred_probs = pickle.load(f)

# Average of the predicted probabilites
ensemble_pred_probs = (xgb_pred_probs +
                       mlp_pred_probs +
                       rf_pred_probs +
                       mnb_pred_probs +
                       lr_pred_probs)/5.0
# Show metrics
display_results(y_test, ensemble_pred_probs)
# Out:
# Test Set Accuracy =  0.707
# Test Set F-score =  0.716
# Test Set Precision =  0.735
# Test Set Recall =  0.713
# Confusion matrix, without normalization
# [[117  11  81   1   3  11]
#  [ 11 175  54   4   8  48]
#  [ 30  28 470   2   7  46]
#  [  0   0   0 247   0   0]
#  [  0   0   3   0 238   0]
#  [ 12  42 159   6   7 139]]
